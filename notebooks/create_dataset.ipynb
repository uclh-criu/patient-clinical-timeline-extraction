# %%
#Imports
import sys
import os

utils_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'utils'))

if utils_path not in sys.path:
    sys.path.insert(0, utils_path)

from medcat_etl import ( load_medcat_export,
    get_validated_entities, get_validated_dates, get_validated_links, get_validated_relative_dates, DATE_CUI, RELATIVE_DATE_CUI,
    doc_to_entities_json, doc_to_dates_json, doc_to_links_json, doc_to_links_value_json, doc_to_relative_dates_json,
    id2value_from_items, make_row
)
import pandas as pd

# %%
#Load data
export_path = "../data/MedCAT_Export_With_Text_2025-09-11_08_19_37.json"
export = load_medcat_export(export_path)

# %%
#Flatten documents
docs = []
for proj in export.get("projects", []):
    for doc in proj.get("documents", []):
        docs.append(doc)

len(docs)
# Out:
# 5

# %% [markdown]
# Testing

# %%
#Pick a document to test
doc = docs[0]
doc
# Out:
# {'id': 26461,
#  'name': '0',
#  'text': "Ultrasound (30nd Jun 2024): no significant findings.imp: asthma\n\nShe denies any nausea, vomiting, or diarrhea.\nC Patient reports compliance with current medication regimen. Basic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.\nPatient is afebrile with normal vital signs. T (02nd Aug 2024): reveals asthma.imp: asthma\n\nX-ray (12nd Sep 2024): shows 3.1cm mass in brain.imp: pituitary_adenoma\n\nCLINIC VISIT (16 Sep'24): nausea/vomiting worsening confirmed rheumatoid_arthritis switch to aspirin\n\nPast medical history is non-contributory.\nURGENT REVIEW (23rd Oct 2024): headache x1 day.r Will order additional laboratory studies at next visit if symptoms persist. Heart: Regular rate and rhythm, no murmurs. Patient has a history of meningitis. GI: Bowel sounds present in all four quadrants.\n Liver function tests show mild elevation in ALT and AST, likely due to medication effect.Chest X-ray reveals clear lung fields without infiltrates or effusions. No hepatosplenomegaly.\nShe denies any nausea, vomiting, or diarrhea. Patient advised to maintain a symptom diary for review at next appointment. esolving pneumonia\n\nMedications were reconciled during the visit.\nF/U (16st Nov 2024): improved.rule out pituitary_adenoma observe and reassess\n\nX-ray (17.12.24): reveals GERD.imp: GERD",
#  'last_modified': '2025-09-04 14:07:54.251476+00:00',
#  'annotations': [{'id': 308244,
#    'user': 'admin',
#    'cui': '161478002',
#    'value': 'history of meningitis',
#    'start': 756,
#    'end': 777,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:03.408411+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308245,
#    'user': 'admin',
#    'cui': '69896004',
#    'value': 'rheumatoid_arthritis',
#    'start': 491,
#    'end': 511,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:02.769353+00:00',
#    'manually_created': False,
#    'acc': 0.81889296323061,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308246,
#    'user': 'admin',
#    'cui': '417662000',
#    'value': 'Past medical history',
#    'start': 531,
#    'end': 551,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:43:09.555324+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {}},
#   {'id': 308248,
#    'user': 'admin',
#    'cui': '513881000000106',
#    'value': 'current medication',
#    'start': 145,
#    'end': 163,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:22.250868+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308249,
#    'user': 'admin',
#    'cui': '72970002',
#    'value': 'normal vital signs',
#    'start': 289,
#    'end': 307,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:45.877405+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308252,
#    'user': 'admin',
#    'cui': '254956000',
#    'value': 'pituitary_adenoma',
#    'start': 410,
#    'end': 427,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:35.077306+00:00',
#    'manually_created': False,
#    'acc': 0.8379077383875848,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308255,
#    'user': 'admin',
#    'cui': '16932000',
#    'value': 'nausea, vomiting',
#    'start': 80,
#    'end': 96,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:00.578170+00:00',
#    'manually_created': False,
#    'acc': 0.7092876553535462,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308258,
#    'user': 'admin',
#    'cui': '16932000',
#    'value': 'nausea/vomiting',
#    'start': 455,
#    'end': 470,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:52.878283+00:00',
#    'manually_created': False,
#    'acc': 0.45190789103507994,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308260,
#    'user': 'admin',
#    'cui': '260394003',
#    'value': 'normal limits',
#    'start': 202,
#    'end': 215,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:26.549129+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308261,
#    'user': 'admin',
#    'cui': '386134007',
#    'value': 'significant',
#    'start': 31,
#    'end': 42,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:53.643163+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308265,
#    'user': 'admin',
#    'cui': '16310003',
#    'value': 'Ultrasound',
#    'start': 0,
#    'end': 10,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:39:04.989736+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308266,
#    'user': 'admin',
#    'cui': '405078008',
#    'value': 'compliance',
#    'start': 129,
#    'end': 139,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:16.185137+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308267,
#    'user': 'admin',
#    'cui': '113075003',
#    'value': 'creatinine',
#    'start': 248,
#    'end': 258,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:34.859808+00:00',
#    'manually_created': False,
#    'acc': 0.5987323015928269,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308269,
#    'user': 'admin',
#    'cui': '230993007',
#    'value': 'worsening',
#    'start': 471,
#    'end': 480,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:55.436325+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308270,
#    'user': 'admin',
#    'cui': '74996004',
#    'value': 'confirmed',
#    'start': 481,
#    'end': 490,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:00.211266+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308273,
#    'user': 'admin',
#    'cui': '75570004',
#    'value': 'pneumonia',
#    'start': 1143,
#    'end': 1152,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:45:25.856663+00:00',
#    'manually_created': False,
#    'acc': -0.020720626413822173,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308274,
#    'user': 'admin',
#    'cui': '62315008',
#    'value': 'diarrhea',
#    'start': 101,
#    'end': 109,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:03.345045+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308275,
#    'user': 'admin',
#    'cui': '86699002',
#    'value': 'afebrile',
#    'start': 275,
#    'end': 283,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:43.161135+00:00',
#    'manually_created': False,
#    'acc': 0.4910415858030319,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308276,
#    'user': 'admin',
#    'cui': '25064002',
#    'value': 'headache',
#    'start': 604,
#    'end': 612,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:29.393540+00:00',
#    'manually_created': False,
#    'acc': 0.4609490025043487,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308281,
#    'user': 'admin',
#    'cui': '116154003',
#    'value': 'Patient',
#    'start': 113,
#    'end': 120,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:05.582362+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308282,
#    'user': 'admin',
#    'cui': '229059009',
#    'value': 'reports',
#    'start': 121,
#    'end': 128,
#    'validated': True,
#    'correct': False,
#    'deleted': True,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:13.251311+00:00',
#    'manually_created': False,
#    'acc': 0.002582766860723497,
#    'meta_anns': {}},
#   {'id': 308283,
#    'user': 'admin',
#    'cui': '116154003',
#    'value': 'Patient',
#    'start': 264,
#    'end': 271,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:39.440087+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308284,
#    'user': 'admin',
#    'cui': '263857004',
#    'value': 'reveals',
#    'start': 328,
#    'end': 335,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:58.439435+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308285,
#    'user': 'admin',
#    'cui': '387458008',
#    'value': 'aspirin',
#    'start': 522,
#    'end': 529,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:04.808729+00:00',
#    'manually_created': False,
#    'acc': 0.6355825634300709,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308287,
#    'user': 'admin',
#    'cui': '17854005',
#    'value': 'Regular',
#    'start': 705,
#    'end': 712,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:44:05.213365+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308288,
#    'user': 'admin',
#    'cui': '414786004',
#    'value': 'murmurs',
#    'start': 733,
#    'end': 740,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:44:14.948586+00:00',
#    'manually_created': False,
#    'acc': 0.8243670755624772,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308289,
#    'user': 'admin',
#    'cui': '410542002',
#    'value': 'present',
#    'start': 796,
#    'end': 803,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:48:09.543170+00:00',
#    'manually_created': False,
#    'acc': 0.08235405161976815,
#    'meta_anns': {}},
#   {'id': 308293,
#    'user': 'admin',
#    'cui': '195967001',
#    'value': 'asthma',
#    'start': 57,
#    'end': 63,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:40:38.911649+00:00',
#    'manually_created': False,
#    'acc': 0.7908919161558152,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308294,
#    'user': 'admin',
#    'cui': '441889009',
#    'value': 'denies',
#    'start': 69,
#    'end': 75,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:40:56.879302+00:00',
#    'manually_created': False,
#    'acc': 0.3228432267904282,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308295,
#    'user': 'admin',
#    'cui': '195967001',
#    'value': 'asthma',
#    'start': 336,
#    'end': 342,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:01.489024+00:00',
#    'manually_created': False,
#    'acc': 0.7119806765019894,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308296,
#    'user': 'admin',
#    'cui': '195967001',
#    'value': 'asthma',
#    'start': 348,
#    'end': 354,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:03.525690+00:00',
#    'manually_created': False,
#    'acc': 0.6827034504711629,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308297,
#    'user': 'admin',
#    'cui': '257585005',
#    'value': 'CLINIC',
#    'start': 429,
#    'end': 435,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:37.615492+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308298,
#    'user': 'admin',
#    'cui': '103391001',
#    'value': 'URGENT',
#    'start': 573,
#    'end': 579,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:11.521969+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308299,
#    'user': 'admin',
#    'cui': '763288003',
#    'value': 'REVIEW',
#    'start': 580,
#    'end': 586,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:15.209517+00:00',
#    'manually_created': False,
#    'acc': 0.172934690117836,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308305,
#    'user': 'admin',
#    'cui': '12738006',
#    'value': 'brain',
#    'start': 399,
#    'end': 404,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:32.505126+00:00',
#    'manually_created': False,
#    'acc': 0.762517549842596,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308306,
#    'user': 'admin',
#    'cui': '721963009',
#    'value': 'order',
#    'start': 627,
#    'end': 632,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:43:32.363755+00:00',
#    'manually_created': False,
#    'acc': 0.6066351565718651,
#    'meta_anns': {}},
#   {'id': 308307,
#    'user': 'admin',
#    'cui': '80891009',
#    'value': 'Heart',
#    'start': 698,
#    'end': 703,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:47:55.809988+00:00',
#    'manually_created': False,
#    'acc': 0.4228552240133286,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308310,
#    'user': 'admin',
#    'cui': '4147007',
#    'value': 'mass',
#    'start': 391,
#    'end': 395,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:30.189299+00:00',
#    'manually_created': False,
#    'acc': 0.884095023572445,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308312,
#    'user': 'admin',
#    'cui': '102304005',
#    'value': 'rule',
#    'start': 1230,
#    'end': 1234,
#    'validated': True,
#    'correct': False,
#    'deleted': True,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:37:56.734512+00:00',
#    'manually_created': False,
#    'acc': -0.032750685885548594,
#    'meta_anns': {}},
#   {'id': 308313,
#    'user': 'admin',
#    'cui': '235595009',
#    'value': 'GERD',
#    'start': 1305,
#    'end': 1309,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:45:30.935705+00:00',
#    'manually_created': False,
#    'acc': 0.08617372149601579,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'affirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True},
#     'experiencer': {'name': 'experiencer',
#      'value': 'patient',
#      'acc': 1.0,
#      'validated': True}}},
#   {'id': 308314,
#    'user': 'admin',
#    'cui': '235595009',
#    'value': 'GERD',
#    'start': 1315,
#    'end': 1319,
#    'validated': True,
#    'correct': False,
#    'deleted': True,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:37:56.752642+00:00',
#    'manually_created': False,
#    'acc': 0.07146339742466808,
#    'meta_anns': {}},
#   {'id': 308315,
#    'user': 'admin',
#    'cui': '732724000',
#    'value': '4.2',
#    'start': 243,
#    'end': 246,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:41:31.506738+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {}},
#   {'id': 308316,
#    'user': 'admin',
#    'cui': '732402004',
#    'value': '0.9',
#    'start': 259,
#    'end': 262,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:37.424723+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308319,
#    'user': 'admin',
#    'cui': '100',
#    'value': '02nd Aug 2024',
#    'start': 312,
#    'end': 325,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:41:54.869296+00:00',
#    'manually_created': True,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308320,
#    'user': 'admin',
#    'cui': '410671006',
#    'value': '30nd Jun 2024',
#    'start': 12,
#    'end': 25,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:40:19.979009+00:00',
#    'manually_created': True,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308321,
#    'user': 'admin',
#    'cui': '410671006',
#    'value': '12nd Sep 2024',
#    'start': 363,
#    'end': 376,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:26.459110+00:00',
#    'manually_created': True,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308322,
#    'user': 'admin',
#    'cui': '410671006',
#    'value': "16 Sep'24",
#    'start': 443,
#    'end': 452,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:42:48.889243+00:00',
#    'manually_created': True,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308323,
#    'user': 'admin',
#    'cui': '410671006',
#    'value': '23rd Oct 2024',
#    'start': 588,
#    'end': 601,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:43:25.635968+00:00',
#    'manually_created': True,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308324,
#    'user': 'admin',
#    'cui': '410671006',
#    'value': '16st Nov 2024',
#    'start': 1205,
#    'end': 1218,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:44:55.675619+00:00',
#    'manually_created': True,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308325,
#    'user': 'admin',
#    'cui': '410671006',
#    'value': '17.12.24',
#    'start': 1286,
#    'end': 1294,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:45:07.249006+00:00',
#    'manually_created': True,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308409,
#    'user': 'admin',
#    'cui': '997531000000108',
#    'value': 'Liver function tests',
#    'start': 828,
#    'end': 848,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:12.336585+00:00',
#    'manually_created': False,
#    'acc': 0.8477586203813553,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308410,
#    'user': 'admin',
#    'cui': '36760000',
#    'value': 'hepatosplenomegaly',
#    'start': 992,
#    'end': 1010,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:41.963819+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308411,
#    'user': 'admin',
#    'cui': '103311002',
#    'value': 'Patient advised to',
#    'start': 1058,
#    'end': 1076,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:44.776173+00:00',
#    'manually_created': False,
#    'acc': 0.5750307410955429,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308412,
#    'user': 'admin',
#    'cui': '405177001',
#    'value': 'medication effect',
#    'start': 899,
#    'end': 916,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:37.714272+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308413,
#    'user': 'admin',
#    'cui': '254956000',
#    'value': 'pituitary_adenoma',
#    'start': 1239,
#    'end': 1256,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:47:40.469186+00:00',
#    'manually_created': False,
#    'acc': 0.6244663493335247,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308414,
#    'user': 'admin',
#    'cui': '16932000',
#    'value': 'nausea, vomiting',
#    'start': 1027,
#    'end': 1043,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:43.572537+00:00',
#    'manually_created': False,
#    'acc': 0.689594441652298,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308415,
#    'user': 'admin',
#    'cui': '390840006',
#    'value': 'next appointment',
#    'start': 1116,
#    'end': 1132,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:48.071361+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308416,
#    'user': 'admin',
#    'cui': '261083004',
#    'value': 'four quadrants',
#    'start': 811,
#    'end': 825,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:10.889975+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308417,
#    'user': 'admin',
#    'cui': '25609006',
#    'value': 'Patient has',
#    'start': 742,
#    'end': 753,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:48:00.711332+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {}},
#   {'id': 308418,
#    'user': 'admin',
#    'cui': '399208008',
#    'value': 'Chest X-ray',
#    'start': 917,
#    'end': 928,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:38.407418+00:00',
#    'manually_created': False,
#    'acc': 0.8146587046891145,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308419,
#    'user': 'admin',
#    'cui': '34922002',
#    'value': 'lung fields',
#    'start': 943,
#    'end': 954,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:40.484678+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308420,
#    'user': 'admin',
#    'cui': '261904005',
#    'value': 'laboratory',
#    'start': 644,
#    'end': 654,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:47:49.101886+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {}},
#   {'id': 308421,
#    'user': 'admin',
#    'cui': '255456001',
#    'value': 'elevation',
#    'start': 859,
#    'end': 868,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:33.075291+00:00',
#    'manually_created': False,
#    'acc': 0.7799373748898505,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308422,
#    'user': 'admin',
#    'cui': '430869004',
#    'value': 'effusions',
#    'start': 978,
#    'end': 987,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:41.348291+00:00',
#    'manually_created': False,
#    'acc': 0.6886716578900813,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308423,
#    'user': 'admin',
#    'cui': '390772001',
#    'value': 'symptoms',
#    'start': 680,
#    'end': 688,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:47:52.719001+00:00',
#    'manually_created': False,
#    'acc': 0.23070115596055984,
#    'meta_anns': {}},
#   {'id': 308424,
#    'user': 'admin',
#    'cui': '62315008',
#    'value': 'diarrhea',
#    'start': 1048,
#    'end': 1056,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:44.120906+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308425,
#    'user': 'admin',
#    'cui': '385630006',
#    'value': 'maintain',
#    'start': 1077,
#    'end': 1085,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:45.645741+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308426,
#    'user': 'admin',
#    'cui': '385425000',
#    'value': 'improved',
#    'start': 1221,
#    'end': 1229,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:50.394636+00:00',
#    'manually_created': False,
#    'acc': 0.3599346268746379,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308427,
#    'user': 'admin',
#    'cui': '224699009',
#    'value': 'studies',
#    'start': 655,
#    'end': 662,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:47:50.797051+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {}},
#   {'id': 308428,
#    'user': 'admin',
#    'cui': '263857004',
#    'value': 'reveals',
#    'start': 929,
#    'end': 936,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:39.213254+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308429,
#    'user': 'admin',
#    'cui': '390772001',
#    'value': 'symptom',
#    'start': 1088,
#    'end': 1095,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:46.214102+00:00',
#    'manually_created': False,
#    'acc': 0.3764686211943627,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308430,
#    'user': 'admin',
#    'cui': '263857004',
#    'value': 'reveals',
#    'start': 1297,
#    'end': 1304,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:52.891261+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308431,
#    'user': 'admin',
#    'cui': '118448000',
#    'value': 'sounds',
#    'start': 789,
#    'end': 795,
#    'validated': True,
#    'correct': False,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': True,
#    'last_modified': '2025-09-04 14:48:07.621283+00:00',
#    'manually_created': False,
#    'acc': 0.4481955587863922,
#    'meta_anns': {}},
#   {'id': 308432,
#    'user': 'admin',
#    'cui': '2931005',
#    'value': 'likely',
#    'start': 885,
#    'end': 891,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:35.859667+00:00',
#    'manually_created': False,
#    'acc': 0.6497708261013032,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308433,
#    'user': 'admin',
#    'cui': '42752001',
#    'value': 'due to',
#    'start': 892,
#    'end': 898,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:36.722526+00:00',
#    'manually_created': False,
#    'acc': 1.0,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308434,
#    'user': 'admin',
#    'cui': '441889009',
#    'value': 'denies',
#    'start': 1016,
#    'end': 1022,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:42.803480+00:00',
#    'manually_created': False,
#    'acc': 0.24297595322132115,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308435,
#    'user': 'admin',
#    'cui': '763288003',
#    'value': 'review',
#    'start': 1106,
#    'end': 1112,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:47.317288+00:00',
#    'manually_created': False,
#    'acc': 0.23936420977115633,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308436,
#    'user': 'admin',
#    'cui': '39211005',
#    'value': 'Bowel',
#    'start': 783,
#    'end': 788,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:05.151698+00:00',
#    'manually_created': False,
#    'acc': 0.5229130801392196,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308437,
#    'user': 'admin',
#    'cui': '263707001',
#    'value': 'clear',
#    'start': 937,
#    'end': 942,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:39.920623+00:00',
#    'manually_created': False,
#    'acc': 0.9876545986533166,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308438,
#    'user': 'admin',
#    'cui': '255604002',
#    'value': 'mild',
#    'start': 854,
#    'end': 858,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:32.013511+00:00',
#    'manually_created': False,
#    'acc': 0.6717212438583375,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308439,
#    'user': 'admin',
#    'cui': '34608000',
#    'value': 'ALT',
#    'start': 872,
#    'end': 875,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:34.217072+00:00',
#    'manually_created': False,
#    'acc': 0.5444493162065314,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type', 'value': 'none', 'acc': 1.0, 'validated': True}}},
#   {'id': 308440,
#    'user': 'admin',
#    'cui': '373679006',
#    'value': 'AST',
#    'start': 880,
#    'end': 883,
#    'validated': True,
#    'correct': True,
#    'deleted': False,
#    'alternative': False,
#    'killed': False,
#    'irrelevant': False,
#    'last_modified': '2025-09-04 14:48:34.913069+00:00',
#    'manually_created': False,
#    'acc': 0.4223469465970993,
#    'meta_anns': {'relevance': {'name': 'relevance',
#      'value': 'present',
#      'acc': 1.0,
#      'validated': True},
#     'presence': {'name': 'presence',
#      'value': 'confirmed',
#      'acc': 1.0,
#      'validated': True},
#     'type': {'name': 'type',
#      'value': 'none',
#      'acc': 1.0,
#      'validated': True}}}],
#  'relations': [{'start_entity': 308321,
#    'start_entity_cui': '410671006',
#    'start_entity_value': '12nd Sep 2024',
#    'start_entity_start_idx': 363,
#    'start_entity_end_idx': 376,
#    'end_entity': 308252,
#    'end_entity_cui': '254956000',
#    'end_entity_value': 'pituitary_adenoma',
#    'end_entity_start_idx': 410,
#    'end_entity_end_idx': 427,
#    'user': 'admin',
#    'relation': 'link',
#    'validated': True},
#   {'start_entity': 308322,
#    'start_entity_cui': '410671006',
#    'start_entity_value': "16 Sep'24",
#    'start_entity_start_idx': 443,
#    'start_entity_end_idx': 452,
#    'end_entity': 308245,
#    'end_entity_cui': '69896004',
#    'end_entity_value': 'rheumatoid_arthritis',
#    'end_entity_start_idx': 491,
#    'end_entity_end_idx': 511,
#    'user': 'admin',
#    'relation': 'link',
#    'validated': True},
#   {'start_entity': 308323,
#    'start_entity_cui': '410671006',
#    'start_entity_value': '23rd Oct 2024',
#    'start_entity_start_idx': 588,
#    'start_entity_end_idx': 601,
#    'end_entity': 308276,
#    'end_entity_cui': '25064002',
#    'end_entity_value': 'headache',
#    'end_entity_start_idx': 604,
#    'end_entity_end_idx': 612,
#    'user': 'admin',
#    'relation': 'link',
#    'validated': True},
#   {'start_entity': 308325,
#    'start_entity_cui': '410671006',
#    'start_entity_value': '17.12.24',
#    'start_entity_start_idx': 1286,
#    'start_entity_end_idx': 1294,
#    'end_entity': 308313,
#    'end_entity_cui': '235595009',
#    'end_entity_value': 'GERD',
#    'end_entity_start_idx': 1305,
#    'end_entity_end_idx': 1309,
#    'user': 'admin',
#    'relation': 'link',
#    'validated': True}]}

# %%
#Get validated entities, dates, relative dates and relationships
ents = get_validated_entities(doc, date_cui=DATE_CUI)
dates = get_validated_dates(doc, date_cui=DATE_CUI)
relative_dates = get_validated_relative_dates(doc, relative_date_cui=RELATIVE_DATE_CUI)
links = get_validated_links(doc, date_cui=DATE_CUI, relative_date_cui=RELATIVE_DATE_CUI)

print("Entities:", len(ents))
print("Dates:", len(dates))
print("Relative dates:", len(relative_dates))
print("Links:", len(links))
# Out:
# Entities: 64
# Dates: 6
# Relative dates: 0
# Links: 4

# %%
#Look at first 5 of each
ents[:5], dates[:5], links[:5]
# Out:
# ([{'id': 308244,
#    'value': 'history of meningitis',
#    'cui': '161478002',
#    'start': 756,
#    'end': 777},
#   {'id': 308245,
#    'value': 'rheumatoid_arthritis',
#    'cui': '69896004',
#    'start': 491,
#    'end': 511},
#   {'id': 308248,
#    'value': 'current medication',
#    'cui': '513881000000106',
#    'start': 145,
#    'end': 163},
#   {'id': 308249,
#    'value': 'normal vital signs',
#    'cui': '72970002',
#    'start': 289,
#    'end': 307},
#   {'id': 308252,
#    'value': 'pituitary_adenoma',
#    'cui': '254956000',
#    'start': 410,
#    'end': 427}],
#  [{'id': 308320, 'value': '30nd Jun 2024', 'start': 12, 'end': 25},
#   {'id': 308321, 'value': '12nd Sep 2024', 'start': 363, 'end': 376},
#   {'id': 308322, 'value': "16 Sep'24", 'start': 443, 'end': 452},
#   {'id': 308323, 'value': '23rd Oct 2024', 'start': 588, 'end': 601},
#   {'id': 308324, 'value': '16st Nov 2024', 'start': 1205, 'end': 1218}],
#  [{'date_id': 308321, 'entity_id': 308252},
#   {'date_id': 308322, 'entity_id': 308245},
#   {'date_id': 308323, 'entity_id': 308276},
#   {'date_id': 308325, 'entity_id': 308313}])

# %%
# Make links human-readable (map IDs to values) using validated items you already extracted
id2value = id2value_from_items(ents, dates, relative_dates)  # FIX: Add relative_dates

readable_links = [
    {
        "date_id": L["date_id"],
        "date_value": id2value.get(L["date_id"]),
        "entity_id": L["entity_id"],
        "entity_value": id2value.get(L["entity_id"]),
    }
    for L in links
]
readable_links
# Out:
# [{'date_id': 308321,
#   'date_value': '12nd Sep 2024',
#   'entity_id': 308252,
#   'entity_value': 'pituitary_adenoma'},
#  {'date_id': 308322,
#   'date_value': "16 Sep'24",
#   'entity_id': 308245,
#   'entity_value': 'rheumatoid_arthritis'},
#  {'date_id': 308323,
#   'date_value': '23rd Oct 2024',
#   'entity_id': 308276,
#   'entity_value': 'headache'},
#  {'date_id': 308325,
#   'date_value': '17.12.24',
#   'entity_id': 308313,
#   'entity_value': 'GERD'}]

# %%
#Run across all documents and summarize counts
summary = []
for d in docs:
    summary.append({
        "doc_id": d.get("id"),
        "n_entities": len(get_validated_entities(d, DATE_CUI)),
        "n_dates": len(get_validated_dates(d, DATE_CUI)),
        "n_rel_dates": len(get_validated_relative_dates(d, RELATIVE_DATE_CUI)),
        "n_links": len(get_validated_links(d, DATE_CUI, RELATIVE_DATE_CUI)),
    })

pd.DataFrame(summary).sort_values("doc_id").reset_index(drop=True)
# Out:
#    doc_id  n_entities  n_dates  n_rel_dates  n_links
# 0   26461          64        6            0        4
# 1   26462          21        7            0       11
# 2   26463          15        7            0       12
# 3   26464          11        3            0        6
# 4   26465          24        3            0        4

# %% [markdown]
# Create Dataset & Add Relative Dates

# %%
#Extract validated entities, dates, relative dates and links from all docs in dataset and append to rows
rows = []
for doc in docs:
    # Extract entities, dates, relative dates and links
    ents = get_validated_entities(doc, DATE_CUI)
    dates = get_validated_dates(doc, DATE_CUI)
    relative_dates = get_validated_relative_dates(doc, RELATIVE_DATE_CUI)
    links = get_validated_links(doc, DATE_CUI, RELATIVE_DATE_CUI)  # FIX: Add relative_date_cui parameter

    # Mapping from validated items
    id2value = id2value_from_items(ents, dates, relative_dates)

    # Serialize each field
    entities_json = doc_to_entities_json(ents)
    dates_json = doc_to_dates_json(dates)
    relative_dates_json = doc_to_relative_dates_json(relative_dates)
    links_json = doc_to_links_value_json(links, id2value)

    # Assemble row
    rows.append(make_row(
        doc_id=doc.get("id"),
        note_text=doc.get("text", ""),
        entities_json=entities_json,
        dates_json=dates_json,
        relative_dates_json=relative_dates_json,
        links_json=links_json
    ))

# %%
#Create dataframe
df = pd.DataFrame(rows, columns=["doc_id", "note_text", "entities_json", "dates_json", "relative_dates_json", "links_json"])
df
# Out:
#    doc_id                                          note_text  \
# 0   26461  Ultrasound (30nd Jun 2024): no significant fin...
# 1   26462  Labs (27th Sep 2024): anemia. resolving  Skin:...
# 2   26463  URGENT REVIEW (2024-10-04): cough. suspect ost...
# 3   26464  URGENT REVIEW (13rd Feb 2025) MRI of the brain...
# 4   26465  New pt((18/11/24)): pt presents with nausea/vo...
#
#                                        entities_json  \
# 0  [{"id": 308244, "value": "history of meningiti...
# 1  [{"id": 308371, "value": "lesions", "cui": "52...
# 2  [{"id": 308886, "value": "frequent urination",...
# 3  [{"id": 308951, "value": "multiple_sclerosis",...
# 4  [{"id": 308998, "value": "history of neoplasm ...
#
#                                           dates_json relative_dates_json  \
# 0  [{"id": 308320, "value": "30nd Jun 2024", "sta...                  []
# 1  [{"id": 308581, "value": "22/11/24", "start": ...                  []
# 2  [{"id": 308940, "value": "2024-10-04", "start"...                  []
# 3  [{"id": 308996, "value": "05-03-2025", "start"...                  []
# 4  [{"id": 309070, "value": "18/11/24", "start": ...                  []
#
#                                           links_json
# 0  [{"date": "12nd Sep 2024", "entity": "pituitar...
# 1  [{"date": "27th Sep 2024", "entity": "anemia"}...
# 2  [{"date": "2024-10-04", "entity": "cough"}, {"...
# 3  [{"date": "13rd Feb 2025", "entity": "visual"}...
# 4  [{"date": "18/11/24", "entity": "nausea/vomiti...

# %%
#Save csv
out_path = "../data/medcat_trainer_dataset.csv"
df.to_csv(out_path, index=False)
