# %%
#Imports
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from transformers import AutoTokenizer, Trainer, TrainingArguments, EarlyStoppingCallback, set_seed
from datasets import Dataset
import evaluate

# Import our modules
import sys
import os

scripts_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'scripts'))
if scripts_path not in sys.path:
    sys.path.insert(0, scripts_path)

from utils import load_data, prepare_all_samples
from bert_training import create_training_pairs, handle_class_imbalance, add_special_tokens, tokenize_function, compute_metrics
from bert_extractor import preprocess_input, bert_extraction
from bert_model import BertRC

# %%
#Set seed
set_seed(42)

# %%
#Data loading
df = load_data("../data/synthetic.csv")
df
# Out:
#      patient  note_id                                               note  \
# 0          1        0  Ultrasound (30nd Jun 2024): no significant fin...
# 1          2        1  Labs (27th Sep 2024): anemia. resolving  Skin:...
# 2          3        2  URGENT REVIEW (2024-10-04): cough. suspect ost...
# 3          4        3  URGENT REVIEW (13rd Feb 2025) MRI of the brain...
# 4          5        4  New pt((18/11/24)): pt presents with nausea/vo...
# ..       ...      ...                                                ...
# 96         7       96  Visit((08/10/24)): pt presents with joint pain...
# 97         8       97  F/U (31 Aug 2024): resolved A review of system...
# 98         9       98  Phone note((12-10-2024)): slightly improved. o...
# 99        10       99  F/U (2025-02-23): fluctuating. confirmed multi...
# 100        1      100  CLINIC VISIT (15/06/2025): Patient was Current...
#
#     document_timestamp                                extracted_disorders  \
# 0           14/05/2025  [{'label': 'asthma', 'start': 57, 'end': 63}, ...
# 1           14/05/2025  [{'label': 'multiple_sclerosis', 'start': 307,...
# 2           14/05/2025  [{'label': 'osteoarthritis', 'start': 43, 'end...
# 3           14/05/2025  [{'label': 'schizophrenia', 'start': 437, 'end...
# 4           14/05/2025  [{'label': 'diabetes_mellitus', 'start': 440, ...
# ..                 ...                                                ...
# 96          14/05/2025  [{'label': 'macroadenoma', 'start': 112, 'end'...
# 97          14/05/2025  [{'label': 'macroadenoma', 'start': 315, 'end'...
# 98          14/05/2025  [{'label': 'tension_headache', 'start': 108, '...
# 99          14/05/2025  [{'label': 'multiple_sclerosis', 'start': 41, ...
# 100         14/05/2025  [{'label': 'pituitary_adenoma', 'start': 778, ...
#
#                                        formatted_dates  \
# 0    [{'original': '(02nd Aug 2024)', 'parsed': '20...
# 1    [{'original': '(27th Sep 2024)', 'parsed': '20...
# 2    [{'original': '(2024-10-04)', 'parsed': '2004-...
# 3    [{'original': '(13rd Feb 2025)', 'parsed': '20...
# 4    [{'original': '(18/11/24)', 'parsed': '2024-11...
# ..                                                 ...
# 96   [{'original': '(11/12/2024)', 'parsed': '2024-...
# 97   [{'original': '(31 Aug 2024)', 'parsed': '2024...
# 98   [{'original': '(01/03/2025)', 'parsed': '2025-...
# 99   [{'original': '(2025-02-23)', 'parsed': '2023-...
# 100  [{'original': '(15/06/2025)', 'parsed': '2025-...
#
#                                      relationship_gold
# 0    [{'date': '2024-08-02', 'date_position': 311, ...
# 1    [{'date': '2024-09-27', 'date_position': 5, 'd...
# 2    [{'date': '2024-10-04', 'date_position': 16, '...
# 3    [{'date': '2025-02-13', 'date_position': 14, '...
# 4    [{'date': '2024-11-18', 'date_position': 7, 'd...
# ..                                                 ...
# 96   [{'date': '2024-12-11', 'date_position': 624, ...
# 97   [{'date': '2024-08-31', 'date_position': 4, 'd...
# 98   [{'date': '2025-03-01', 'date_position': 228, ...
# 99   [{'date': '2025-02-23', 'date_position': 6, 'd...
# 100  [{'date': '2025-06-15', 'date_position': 13, '...
#
# [101 rows x 7 columns]

# %%
#Prepare samples
samples = prepare_all_samples(df)
samples
# Out:
# [{'note_text': "Ultrasound (30nd Jun 2024): no significant findings.imp: asthma\n\nShe denies any nausea, vomiting, or diarrhea.\nC Patient reports compliance with current medication regimen. Basic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.\nPatient is afebrile with normal vital signs. T (02nd Aug 2024): reveals asthma.imp: asthma\n\nX-ray (12nd Sep 2024): shows 3.1cm mass in brain.imp: pituitary_adenoma\n\nCLINIC VISIT (16 Sep'24): nausea/vomiting worsening confirmed rheumatoid_arthritis switch to aspirin\n\nPast medical history is non-contributory.\nURGENT REVIEW (23rd Oct 2024): headache x1 day.r Will order additional laboratory studies at next visit if symptoms persist. Heart: Regular rate and rhythm, no murmurs. Patient has a history of meningitis. GI: Bowel sounds present in all four quadrants.\n Liver function tests show mild elevation in ALT and AST, likely due to medication effect.Chest X-ray reveals clear lung fields without infiltrates or effusions. No hepatosplenomegaly.\nShe denies any nausea, vomiting, or diarrhea. Patient advised to maintain a symptom diary for review at next appointment. esolving pneumonia\n\nMedications were reconciled during the visit.\nF/U (16st Nov 2024): improved.rule out pituitary_adenoma observe and reassess\n\nX-ray (17.12.24): reveals GERD.imp: GERD",
#   'entities_list': [{'label': 'asthma', 'start': 57, 'end': 63},
#    {'label': 'pituitary_adenoma', 'start': 410, 'end': 427},
#    {'label': 'rheumatoid_arthritis', 'start': 491, 'end': 511},
#    {'label': 'pneumonia', 'start': 1143, 'end': 1152},
#    {'label': 'gerd', 'start': 1305, 'end': 1309},
#    {'label': 'meningitis', 'start': 767, 'end': 777}],
#   'dates': [{'original': '(02nd Aug 2024)',
#     'parsed': '2024-08-02',
#     'start': 311,
#     'end': 326},
#    {'original': '(23rd Oct 2024)',
#     'parsed': '2024-10-23',
#     'start': 587,
#     'end': 602}],
#   'relationship_gold': [{'date': '2024-08-02',
#     'date_position': 311,
#     'diagnoses': [{'diagnosis': 'asthma', 'position': 57}]},
#    {'date': '2024-10-23',
#     'date_position': 587,
#     'diagnoses': [{'diagnosis': 'pneumonia', 'position': 1143}]}],
#   'patient_id': 1,
#   'note_id': 0},
#  {'note_text': 'Labs (27th Sep 2024): anemia. resolving  Skin: No rashes, lesions, or abnormal pigmentation. Good turgor and hydration. Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. Respiratory: Clear to auscultation bilaterally. No wheezes, rales, or rhonchi. Assessment includes congenital malformation. multiple_sclerosis\n\nPhone note((22/11/24)): relapse.\nEKG shows normal sinus rhythm without ST changes or conduction abnormalities. taper medication\n\nURGENT REVIEW (26/12/24): weight loss. Will order additional laboratory studies at next visit if symptoms persist. likely bronchitis\n\nURGENT REVIEW (26 Jan 2025): chest pain. resolving multiple_sclerosis\n\nF/U (29th Jan 2025): sta Patient is afebrile with normal vital signs. Skin: No rashes, lesions, or abnormal pigmentation. Good turgor and hydration. Patient was instructed on proper medication administration techniques. ble. suspect tension_headache taper medication\n\nLabs (16/02/25): elevated CRP. consistent w/ GERD\n\nRecommended lifestyle modifications including diet changes and regular exercise.\nFollow-up appointment scheduled in 3 months.\nMRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke.\nMusculoskeletal: Full range of motion in all extremities. No edema or deformity noted.\nLabs (29-03-2025): elevated CRP. confirmed rheumatoid_arthritis',
#   'entities_list': [{'label': 'multiple_sclerosis', 'start': 307, 'end': 325},
#    {'label': 'bronchitis', 'start': 578, 'end': 588},
#    {'label': 'tension_headache', 'start': 894, 'end': 910},
#    {'label': 'gerd', 'start': 974, 'end': 978},
#    {'label': 'rheumatoid_arthritis', 'start': 1326, 'end': 1346},
#    {'label': 'congenital malformation', 'start': 282, 'end': 305}],
#   'dates': [{'original': '(27th Sep 2024)',
#     'parsed': '2024-09-27',
#     'start': 5,
#     'end': 20},
#    {'original': '(29th Jan 2025)',
#     'parsed': '2025-01-29',
#     'start': 665,
#     'end': 680}],
#   'relationship_gold': [{'date': '2024-09-27',
#     'date_position': 5,
#     'diagnoses': [{'diagnosis': 'multiple_sclerosis', 'position': 307}]},
#    {'date': '2025-01-29',
#     'date_position': 665,
#     'diagnoses': [{'diagnosis': 'tension_headache', 'position': 894}]}],
#   'patient_id': 2,
#   'note_id': 1},
#  {'note_text': 'URGENT REVIEW (2024-10-04): cough. suspect osteoarthritis\n\n\nPatient tolerated the procedure well.New patient((10nd Nov 2024)): pt presents w/ cough. rule out bronchitis\n\n Patient tolerated the procedure well.PET scan (21-11-2024): evidence of hemorrhage. imp: GERD\n\nVisit((12nd Jan 2025)): pt presents w/ weight gain. new dx of diabetes_mellitus\n\n Referral placed for physical therapy twice weekly for 6 weeks.CLINIC VISIT (23rd Feb 2025): frequent urination fluctuating consistent w/ anemia schedule MRI\n\n Will order additional laboratory studies at next visit if symptoms persist.Labs (04.04.25): normal chemistry panel. rule out depression\n\nPatient given educational materials regarding disease management.\nF/U (07.05.25): slightly improved. unclear etiology,could be She denies any nausea, vomiting, or diarrhea. MRI of the brain demonstrates age-appropriate atrophy without evidence of ma Urinalysis negative for blood, protein, and leukocyte esterase. Abdomen: Soft, non-tender, non-distended. ss or stroke. HEENT: Normocephalic, atraumatic. Pupils equal, round, and reactive to light.\nRecommended lifestyle modifications including diet changes and regular exercise.  COPD vs hyperlipidemia switch to topiramate\n\nCLINIC VISIT (19/05/25): fever fluctuating unclear etiology,could be IBS vs anemia schedule CT',
#   'entities_list': [{'label': 'osteoarthritis', 'start': 43, 'end': 57},
#    {'label': 'bronchitis', 'start': 158, 'end': 168},
#    {'label': 'gerd', 'start': 260, 'end': 264},
#    {'label': 'diabetes_mellitus', 'start': 328, 'end': 345},
#    {'label': 'anemia', 'start': 485, 'end': 491},
#    {'label': 'depression', 'start': 632, 'end': 642},
#    {'label': 'copd', 'start': 1174, 'end': 1178},
#    {'label': 'hyperlipidemia', 'start': 1182, 'end': 1196},
#    {'label': 'ibs', 'start': 1288, 'end': 1291}],
#   'dates': [{'original': '(2024-10-04)',
#     'parsed': '2004-10-24',
#     'start': 14,
#     'end': 26},
#    {'original': '(07.05.25)',
#     'parsed': '2025-05-07',
#     'start': 714,
#     'end': 724}],
#   'relationship_gold': [{'date': '2024-10-04',
#     'date_position': 16,
#     'diagnoses': [{'diagnosis': 'osteoarthritis', 'position': 43}]},
#    {'date': '2025-05-07',
#     'date_position': 714,
#     'diagnoses': [{'diagnosis': 'copd', 'position': 1174},
#      {'diagnosis': 'hyperlipidemia', 'position': 1182}]}],
#   'patient_id': 3,
#   'note_id': 2},
#  {'note_text': "URGENT REVIEW (13rd Feb 2025) MRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke. HEENT: Normocephalic, atraumatic. Pupils equal, round, and reactive to light. GI: Bowel sounds present in all four quadrants.\nLymphatic: No cervical, axillary, or inguinal lymphadenopathy. No hepatosplenomegaly. The patient's vital signs are stable. Labs from this morning were unremarkable. : visual changes. likely schizophrenia\n\nLabs (05-03-2025): WBC elevated. like Medication dosages were adjusted based on recent laboratory findings. Medications were reconciled during the visit. ly COPD\n\n Patient reports compliance with current medication regimen.Cardiology CONSULT (09 Apr 2025): unclear etiology, could be stroke vs microadenoma follow up in 6 months\n\n Will order additional laboratory studies at next visit if symptoms persist.CT scan of the head shows no acute intracranial abnormalities.\nCurrent medications include: lisinopril 10mg daily, metformin 500mg twice daily, and atorvastatin 20mg at bedtime.\n A review of systems was otherwise negative.X-ray (28st May 2025): no significant findings. imp: multiple_sclerosis\n\nPsychiatric: Alert and oriented x3. Mood and affect appropriate.\nURGENT REVIEW (27rd Jun 2025): fatigue. Medications were reconciled during the visit. consistent with IBS",
#   'entities_list': [{'label': 'schizophrenia', 'start': 437, 'end': 450},
#    {'label': 'copd', 'start': 609, 'end': 613},
#    {'label': 'stroke', 'start': 736, 'end': 742},
#    {'label': 'microadenoma', 'start': 746, 'end': 758},
#    {'label': 'multiple_sclerosis', 'start': 1133, 'end': 1151},
#    {'label': 'ibs', 'start': 1320, 'end': 1323}],
#   'dates': [{'original': '(13rd Feb 2025)',
#     'parsed': '2025-02-13',
#     'start': 14,
#     'end': 412},
#    {'original': '(05-03-2025)',
#     'parsed': '2025-03-05',
#     'start': 457,
#     'end': 469}],
#   'relationship_gold': [{'date': '2025-02-13',
#     'date_position': 14,
#     'diagnoses': [{'diagnosis': 'schizophrenia', 'position': 437}]},
#    {'date': '2025-03-05',
#     'date_position': 457,
#     'diagnoses': [{'diagnosis': 'copd', 'position': 609}]}],
#   'patient_id': 4,
#   'note_id': 3},
#  {'note_text': 'New pt((18/11/24)): pt presents with nausea/vomiting.new di Recommended lifestyle modifications including diet changes and regular exercise. Patient was instructed on proper medication administration techniques. Patient has a history of neoplasm of pituitary gland.\nThe patient was counseled on lifestyle modifications.\nGI: Bowel sounds present in all four quadrants. pituitary macroadenoma was discussed. No hepatosplenomegaly. agnosis of diabetes_mellitus\n MRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke.\n\nPatient is afebrile with normal vital signs.Patient reports compliance with current medication regimen.\n\nLungs clear to auscultation bilaterally.Phone note((2024-12-14)): improved.increase dose\n She denies any nausea, vomiting, or diarrhea.\n\n\nComplete blood count shows WBC 7.2, Hgb 13.5, Plt 250.Liver function tests show mild elevation in ALT and AST, likely due to medication effect.\n Patient was instructed on proper medication administration techniques.\nLabs from this morning were unremarkable.Past medical history is non-contributory. Noted congenital malformation in medical history.\n\nCurrent medications include: lisinopril 10mg daily, metformin 500mg twice daily, and atorvastatin 20mg at bedtime. Patient has a history of cerebral hemorrhage. Patient has a history of disorder of optic nerve.\nUrinalysis negative for blood, protein, and leukocyte esterase.Urinalysis negative for blood, protein, and leukocyte esterase.F/U (12/02/25): unchanged.consistent with diabetes_mellitus continue current medications',
#   'entities_list': [{'label': 'diabetes_mellitus', 'start': 440, 'end': 457},
#    {'label': 'disorder of optic nerve', 'start': 1329, 'end': 1352},
#    {'label': 'pituitary macroadenoma', 'start': 368, 'end': 390},
#    {'label': 'cerebral hemorrhage', 'start': 1283, 'end': 1302},
#    {'label': 'congenital malformation', 'start': 1098, 'end': 1121},
#    {'label': 'neoplasm of pituitary gland', 'start': 237, 'end': 264}],
#   'dates': [{'original': '(18/11/24)',
#     'parsed': '2024-11-18',
#     'start': 7,
#     'end': 17},
#    {'original': '(2024-12-14)',
#     'parsed': '2014-12-24',
#     'start': 706,
#     'end': 718}],
#   'relationship_gold': [{'date': '2024-11-18',
#     'date_position': 7,
#     'diagnoses': [{'diagnosis': 'diabetes_mellitus', 'position': 440}]}],
#   'patient_id': 5,
#   'note_id': 4},
#  {'note_text': 'CLINIC VISIT (2024-08-06): dizziness progressive new .dx of bipolar_disorder schedule X-ray\n\n\nNeurological exam within normal limits.PET scan (29/09/24): evidence of stenosis. imp: hypothyroidism\n\n Patient reports occasional use of over-the-counter analgesics for pain management.She denies any nausea, vomiting, or diarrhea.\n\n\nHEENT: Normocephalic, atraumatic. Pupils equal, round, and reactive to light. Urinalysis negative for blood, protein, and leukocyte esterase.Patient instructed to follow up with specialist for further evaluation.MRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke.\nPsychiatric: Alert and oriented x3. Mood and affect appropriate.\nPhone note((06/11/2024)): stable.\nPatient advised to maintain a symptom diary for review at next appointment. taper medication\n\nX-ray (09st Dec 2024): reveals diabetes_mellitus. imp: diabetes_mellitus\n\n\nGI: Bowel sounds present in all four quadrants. No hepatosplenomegaly.Visit((28rd Dec 2024)): pt presents with abdominal pain. confirmed anxiety\n\nLabs (2025-02-07): low vitamin D.\nThe patient was advised to return if symptoms worsen. resolving pituitary_adenoma\n\nEKG shows normal sinus rhythm without ST changes or conduction abnormalities.\nPhone note((15 Feb 2025)): fluctuating. pituitary adenoma was discussed. taper medication',
#   'entities_list': [{'label': 'bipolar_disorder', 'start': 60, 'end': 76},
#    {'label': 'hypothyroidism', 'start': 181, 'end': 195},
#    {'label': 'diabetes_mellitus', 'start': 854, 'end': 871},
#    {'label': 'anxiety', 'start': 1035, 'end': 1042},
#    {'label': 'pituitary_adenoma', 'start': 1142, 'end': 1159},
#    {'label': 'pituitary adenoma', 'start': 1279, 'end': 1296}],
#   'dates': [{'original': '(2024-08-06)',
#     'parsed': '2006-08-24',
#     'start': 13,
#     'end': 25},
#    {'original': '(15 Feb 2025)',
#     'parsed': '2025-02-15',
#     'start': 1250,
#     'end': 1263}],
#   'relationship_gold': [{'date': '2024-08-06',
#     'date_position': 15,
#     'diagnoses': [{'diagnosis': 'bipolar_disorder', 'position': 60}]},
#    {'date': '2025-02-07',
#     'date_position': 7,
#     'diagnoses': [{'diagnosis': 'pituitary_adenoma', 'position': 1142}]}],
#   'patient_id': 6,
#   'note_id': 5},
#  {'note_text': 'New pt((08-06-2024)): pt presents w/ back pai Patient tolerated the procedure well. Patient reports occasional use of over-the-counter analgesics for pain management. Imaging studies were reviewed with the patient. cerebral hemorrhage was discussed. Will continue current medication regimen and reassess in 3 months. congenital malformation was discussed. n.consistent w/ bipolar_disorder\n Medication dosages were adjusted based on recent laboratory findings. Patient has a history of disorder of pituitary gland. Patient given educational materials regarding disease management.\n\nLabs from this morning were unremarkable.URGENT REVIEW (03rd Jul 2024): weight gain.rule out Patient advised to maintain a symptom diary for review at next appointment. Patient tolerated the procedure well. Liver function tests show mild elevation in ALT and AST, likely due to medication effect. Patient advised to maintain a symptom diary for review at next appointment. No acute distress noted on examination. Patient given educational materials regarding disease management. Patient given educational materials regarding disease management.  asthma\n\nThe patient was advised to return if symptoms worsen.\n\nUrinalysis negative for blood, protein, and leukocyte esterase.\nChest X-ray reveals clear lung fields without infiltrates or effusions.Rheumatology CONSULT (26nd Aug 2024): likely schizophrenia observe and reassess',
#   'entities_list': [{'label': 'bipolar_disorder', 'start': 372, 'end': 388},
#    {'label': 'asthma', 'start': 1127, 'end': 1133},
#    {'label': 'schizophrenia', 'start': 1370, 'end': 1383},
#    {'label': 'congenital malformation', 'start': 317, 'end': 340},
#    {'label': 'cerebral hemorrhage', 'start': 215, 'end': 234},
#    {'label': 'disorder of pituitary gland', 'start': 485, 'end': 512}],
#   'dates': [{'original': '(08-06-2024)',
#     'parsed': '2024-06-08',
#     'start': 7,
#     'end': 19},
#    {'original': '(03rd Jul 2024)',
#     'parsed': '2024-07-03',
#     'start': 636,
#     'end': 651}],
#   'relationship_gold': [{'date': '2024-06-08',
#     'date_position': 7,
#     'diagnoses': [{'diagnosis': 'bipolar_disorder', 'position': 372}]},
#    {'date': '2024-07-03',
#     'date_position': 636,
#     'diagnoses': [{'diagnosis': 'asthma', 'position': 1127}]}],
#   'patient_id': 7,
#   'note_id': 6},
#  {'note_text': "CLINIC VISIT (17rd Dec 2024): insomnia resolved new diagnosis of COPD taper medication\n\nHe denies any fever, chills, or night sweats.\n No acute distress noted on examination. Abdomen: Soft, non-tender, non-distended.CLINIC VISIT (15 Feb'25): fatigue progressive confirmed IBS admit to hospital\n\n\nComplete blood count shows WBC 7.2, Hgb 13.5, Plt 250. Patient tolerated the procedure well.Ultrasound (02 Mar 2025): reveals Liver function tests show mild elevation in ALT and AST, likely due to medication effect. No known drug allergies or adverse reactions reported. Patient has a history of soft tissue lesion. Patient is afebrile with normal vital signs.  tension_headache. imp: tension_headache\n\nPatient advised to maintain a symptom diary for review at next appointment.\n\nWill order additional laboratory studies at next visit if symptoms persist.Labs (07.03.25): abnormal LFTs.\nBasic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9. rule  Basic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9. Patient given educational materials regarding disease management. The plan was discussed with the patient, who understands and agrees. out ulcerative_colitis\n\nUltrasound (24.03.25): evidence of lesion. Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. imp: leukemia",
#   'entities_list': [{'label': 'copd', 'start': 65, 'end': 69},
#    {'label': 'ibs', 'start': 272, 'end': 275},
#    {'label': 'tension_headache', 'start': 658, 'end': 674},
#    {'label': 'ulcerative_colitis', 'start': 1210, 'end': 1228},
#    {'label': 'leukemia', 'start': 1341, 'end': 1349},
#    {'label': 'soft tissue lesion', 'start': 592, 'end': 610}],
#   'dates': [{'original': '(02 Mar 2025)',
#     'parsed': '2025-03-02',
#     'start': 399,
#     'end': 412},
#    {'original': '(07.03.25)',
#     'parsed': '2025-03-07',
#     'start': 856,
#     'end': 866}],
#   'relationship_gold': [{'date': '2025-03-02',
#     'date_position': 399,
#     'diagnoses': [{'diagnosis': 'tension_headache', 'position': 658}]},
#    {'date': '2025-03-07',
#     'date_position': 856,
#     'diagnoses': [{'diagnosis': 'ulcerative_colitis', 'position': 1210}]}],
#   'patient_id': 8,
#   'note_id': 7},
#  {'note_text': 'CLINIC VISIT (21st Jan 2025): insomnia  Abdomen: Soft, non-tender, non-distended. Cardiovascular: Regular rate and rhythm. No murmurs, rubs, or gallops. Normal S1 and S2. progressive confirmed schizophrenia cont current medications\n\nPatient was instructed on proper medication administration techniques.\n Complete blood count shows WBC 7.2, Hgb 13.5, Plt 250.CT (09 Feb 2025): shows 2.7cm mass in thyroid. Will order additional laboratory studies at next visit if symptoms persist. imp: hypothyroidism\n\n\nPatient is afebrile with normal vital signs.URGENT REVIEW (24/03/2025): cough.\nWill order additional laboratory studies at next visit if symptoms persist. unclear etiology,could be ulcerative_colitis vs microadenoma\n\nLabs (28th Apr 2025): abnormal LFTs. su Lungs clear to auscultation bilaterally. Imaging studies were reviewed with the patient. Medication dosages were adjusted based on recent laboratory findings. spect COPD\n\nEKG shows normal sinus rhythm without ST changes or conduction abnormalities.\n\n Heart: Regular rate and rhythm, no murmurs.Medication dosages were adjusted based on recent laboratory findings.CLINIC VISIT (26.06.25): visual changes worsening unclear etiology,could be osteoarthritis vs diabetes_mellitus increase dos,e\n\nPET scan (06nd Aug 2025): reveals ulcerative_colitis. imp: ulcerative_colitis',
#   'entities_list': [{'label': 'schizophrenia', 'start': 193, 'end': 206},
#    {'label': 'hypothyroidism', 'start': 487, 'end': 501},
#    {'label': 'ulcerative_colitis', 'start': 685, 'end': 703},
#    {'label': 'microadenoma', 'start': 707, 'end': 719},
#    {'label': 'copd', 'start': 926, 'end': 930},
#    {'label': 'osteoarthritis', 'start': 1200, 'end': 1214},
#    {'label': 'diabetes_mellitus', 'start': 1218, 'end': 1235}],
#   'dates': [{'original': '(21st Jan 2025)',
#     'parsed': '2025-01-21',
#     'start': 13,
#     'end': 28},
#    {'original': '(28th Apr 2025)',
#     'parsed': '2025-04-28',
#     'start': 726,
#     'end': 741}],
#   'relationship_gold': [{'date': '2025-01-21',
#     'date_position': 13,
#     'diagnoses': [{'diagnosis': 'schizophrenia', 'position': 193}]},
#    {'date': '2025-04-28',
#     'date_position': 726,
#     'diagnoses': [{'diagnosis': 'copd', 'position': 926}]}],
#   'patient_id': 9,
#   'note_id': 8},
#  {'note_text': 'Ultrasound (06 Oct 2024): evidence of mass effect.imp: pituitary_adenoma\n\nLabs (19.10.24): normal CBC.consistent  Patient given educational materials regarding disease management. Current medications include: lisinopril 10mg daily, metformin 500mg twice daily, and atorvastatin 20mg at bedtime. with macroadenoma\n\nLabs from this morning were unremarkable.\n Past medical history is non-contributory. Patient tolerated the procedure well. She denies any nausea, vomiting, or diarrhea.Labs (24st Nov 2024): anemia.rule out epilepsy\n\nBasic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.\nNeurological exam within normal limits.\nInternal Medicine CONSULT (02nd Jan 2025): unclear No acute distress noted on examination.\nBasic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9. Complete blood count shows WBC 7.2, Hgb 13.5, Plt 250. Patient has a history of pituitary macroadenoma. Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. Recommended lifestyle modifications including diet changes and regular exercise. Heart: Regular rate and rhythm, no murmurs. HEENT: Normocephalic, atraumatic.\nCardiovascular: Regular rate and rhythm. No murmurs, rubs, or gallops. Normal S1 and S2. Pupils equal, round, and reactive to light.  etiology,could be GERD vs multiple_sclerosis schedule CT',
#   'entities_list': [{'label': 'pituitary_adenoma', 'start': 55, 'end': 72},
#    {'label': 'macroadenoma', 'start': 300, 'end': 312},
#    {'label': 'epilepsy', 'start': 520, 'end': 528},
#    {'label': 'gerd', 'start': 1321, 'end': 1325},
#    {'label': 'multiple_sclerosis', 'start': 1329, 'end': 1347},
#    {'label': 'pituitary macroadenoma', 'start': 923, 'end': 945}],
#   'dates': [{'original': '(19.10.24)',
#     'parsed': '2024-10-19',
#     'start': 79,
#     'end': 89},
#    {'original': '(02nd Jan 2025)',
#     'parsed': '2025-01-02',
#     'start': 687,
#     'end': 702}],
#   'relationship_gold': [{'date': '2024-10-19',
#     'date_position': 79,
#     'diagnoses': [{'diagnosis': 'macroadenoma', 'position': 300}]},
#    {'date': '2025-01-02',
#     'date_position': 687,
#     'diagnoses': [{'diagnosis': 'gerd', 'position': 1321},
#      {'diagnosis': 'multiple_sclerosis', 'position': 1329}]}],
#   'patient_id': 10,
#   'note_id': 9},
#  {'note_text': "Cardiology CONSULT (08-06-2024): suspect Cushing's_syndrome schedule MRI\n\nPatient reports occasional use of over-the-counter analgesics for pain management.\nPhone note((28.06.24)): worsening. Patient tolerated the procedure well. cont current medications\n\nURGENT REVIEW (05st Jul 2024): insomn A review of systems was otherwise negative. A review of systems was otherwise negative. Patient is afebrile with normal vital signs. Medications were reconciled during the visit. Current medications include: lisinopril 10mg daily, metformin 500mg twice daily, and atorvastatin 20mg at bedtime. Noted depression in medical history. GI: Bowel sounds present in all four quadrants. No hepatosplenomegaly. Noted pituitary macroadenoma in medical history. ia. suspect multiple_sclerosis\n\nNo acute distress noted on examination. Patient instructed to follow up with specialist for further evaluation.\nF/U (31 Aug 2024): stable. rule out Parkinson's_disease f/u in 1 month\n Medications were reconciled during the visit.\n Patient reports occasional use of over-the-counter analgesics for pain management.CLINIC VISIT (11 Oct 2024): insomnia unchanged unclear etiology,could be prolactinoma vs bronchitis observe and reassess\n\nCardiology CONSULT (13/10/24): resolving Cushing's_syndrome schedule MRI\n\nPhone note((04/11/2024)): stable. switch to ibuprofen\n\nF/U (28 Nov'24): fluctuating. rule out anemia switch to ibuprofen",
#   'entities_list': [{'label': 'multiple_sclerosis', 'start': 757, 'end': 775},
#    {'label': 'prolactinoma', 'start': 1163, 'end': 1175},
#    {'label': 'bronchitis', 'start': 1179, 'end': 1189},
#    {'label': 'anemia', 'start': 1380, 'end': 1386},
#    {'label': 'depression', 'start': 594, 'end': 604},
#    {'label': 'pituitary macroadenoma', 'start': 702, 'end': 724}],
#   'dates': [{'original': '(05st Jul 2024)',
#     'parsed': '2024-07-05',
#     'start': 270,
#     'end': 285},
#    {'original': '(13/10/24)',
#     'parsed': '2024-10-13',
#     'start': 1231,
#     'end': 1241}],
#   'relationship_gold': [{'date': '2024-07-05',
#     'date_position': 270,
#     'diagnoses': [{'diagnosis': 'multiple_sclerosis', 'position': 757}]}],
#   'patient_id': 1,
#   'note_id': 10},
#  {'note_text': "URGENT REVIEW (25rd May 2024): weig The patient's vital signs are stable. Will continue current medication regimen and reassess in 3 months.\nBasic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9. Patient given educational materials regarding disease management. Liver function tests show mild elevation in ALT and AST, likely due to medication effect.\n Psychiatric: Alert and oriented x3. Assessment includes disorder of pituitary gland. Mood and affect appropriate.A review of systems was otherwise negative. Noted atrial fibrillation in medical history.\nChest X-ray reveals clear lung fields without infiltrates or effusions. Assessment includes congenital malformation.\nHe denies any fever, chills, or night sweats.\nFollow-up appointment scheduled in 3 months. Follow-up appointment scheduled in 3 months. ht loss.consistent with rheumatoid_arthritis\n The plan was discussed with the patient, who understands and agrees. Heart: Regular rate and rhythm, no murmurs.\n Labs from this morning were unremarkable.Patient instructed to follow up with specialist for further evaluation. HEENT: Normocephalic, atraumatic. Pupils equal, round, and reactive to light.\nCLINIC VISIT (29st Jun 2024): shortness of breath remission rule out IBS increase dose\n\n\nHeart: Regular rate and rhythm, no murmurs.F/U (2024-08-02): relapse.consistent with cluster_headache observe and reassess",
#   'entities_list': [{'label': 'rheumatoid_arthritis',
#     'start': 869,
#     'end': 889},
#    {'label': 'ibs', 'start': 1265, 'end': 1268},
#    {'label': 'cluster_headache', 'start': 1370, 'end': 1386},
#    {'label': 'atrial fibrillation', 'start': 552, 'end': 571},
#    {'label': 'congenital malformation', 'start': 684, 'end': 707},
#    {'label': 'disorder of pituitary gland', 'start': 445, 'end': 472}],
#   'dates': [{'original': '(25rd May 2024)',
#     'parsed': '2024-05-25',
#     'start': 14,
#     'end': 29},
#    {'original': '(2024-08-02)',
#     'parsed': '2002-08-24',
#     'start': 1332,
#     'end': 1344}],
#   'relationship_gold': [{'date': '2024-05-25',
#     'date_position': 14,
#     'diagnoses': [{'diagnosis': 'rheumatoid_arthritis', 'position': 869}]},
#    {'date': '2024-08-02',
#     'date_position': 6,
#     'diagnoses': [{'diagnosis': 'cluster_headache', 'position': 1370}]}],
#   'patient_id': 2,
#   'note_id': 11},
#  {'note_text': "Labs (25 Jun'24): anemia.confirmed Crohn's_disease\n No acute distress noted on examination.\nF/U (03 Jul'24): fluctuati The patient's vital signs are stable.\n\nPast medical history is non-contributory.Patient is afebrile with normal vital signs. Assessment includes congenital malformation. cerebral hemorrhage was discussed.\nFollow-up appointment scheduled in 3 months. Will continue current medication regimen and reassess in 3 months.\nPatient advised to maintain a symptom diary for review at next appointment. Patient tolerated the procedure well. ng.suspect gout admit to hospital\n Patient advised to maintain a symptom diary for review at next appointment. Chest X-ray reveals clear lung fields without infiltrates or effusions.\n EKG shows normal sinus rhythm without ST changes or conduction abnormalities.Phone note((15st Jul 2024)): relapse.admit to hospital\n\nUrinalysis negative for blood, protein, and leukocyte esterase.\nHeart: Regular rate and rhythm, no murmurs.\nPsychiatry CONSULT (02nd Aug 2024): resolving asthma taper medication\n CT scan of the head shows no acute intracranial abnormalities. type 2 diabetes was discussed.\nF/U (20/09/2024): fluctuating.confirmed hyperlipidemia schedule PET scan\n CT scan of the head shows no acute intracranial abnormalities.\nNeurological exam within normal limits.\nPhone note((07.10.24)): fluctuating.continue current medications",
#   'entities_list': [{'label': 'gout', 'start': 561, 'end': 565},
#    {'label': 'asthma', 'start': 1021, 'end': 1027},
#    {'label': 'hyperlipidemia', 'start': 1180, 'end': 1194},
#    {'label': 'cerebral hemorrhage', 'start': 289, 'end': 308},
#    {'label': 'type 2 diabetes', 'start': 1109, 'end': 1124},
#    {'label': 'congenital malformation', 'start': 264, 'end': 287}],
#   'dates': [{'original': "(03 Jul'24)",
#     'parsed': '2024-07-03',
#     'start': 96,
#     'end': 107},
#    {'original': '(15st Jul 2024)',
#     'parsed': '2024-07-15',
#     'start': 822,
#     'end': 837}],
#   'relationship_gold': [{'date': '2024-07-03',
#     'date_position': 96,
#     'diagnoses': [{'diagnosis': 'gout', 'position': 561}]}],
#   'patient_id': 3,
#   'note_id': 12},
#  {'note_text': "Phone note((30rd Dec 2024)): progressive. cont current medications\n\n\nThe patient was counseled on lifestyle modifications.Phone note((17st Jan 2025)): relapse. switch to metformin\n\n\nChest X-ray reveals clear lung fields without infiltrates or effusions. Imaging studies were reviewed with the patient.Ultrasound (19rd Jan 2025): shows 0.5cm mass in thyroid.\nPatient is afebrile with normal vital signs. imp: adrenal_insufficiency\n\nURGENT REVIEW (26st Feb 2025): weight gain. new Patient given educational materials regarding disease management. Medications were reconciled during the visit. Patient reports occasional use of over-the-counter analgesics for pain management. CT scan of the head shows no acute intracranial abnormalities.  diagnosis of fibromyalgia\n\n\nMusculoskeletal: Full range of motion in all extremities. No edema or deformity noted.Patient reports compliance with current medication regimen. No known drug allergies or adverse reactions reported.\nVisit((06 Apr 2025)): pt presents with fever.\nNeurological exam within normal limits.\nPatient is afebrile with normal vital signs. unclear etiology, could be anxiety vs COPD\n\nCLINIC VISIT (2025-04-12): back pain resolved likely hypothyroidism observe and reassess\n\nX-ray (08 May'25): reveals migraine. imp: migraine",
#   'entities_list': [{'label': 'adrenal_insufficiency',
#     'start': 408,
#     'end': 429},
#    {'label': 'fibromyalgia', 'start': 751, 'end': 763},
#    {'label': 'anxiety', 'start': 1125, 'end': 1132},
#    {'label': 'copd', 'start': 1136, 'end': 1140},
#    {'label': 'hypothyroidism', 'start': 1195, 'end': 1209},
#    {'label': 'migraine', 'start': 1259, 'end': 1267}],
#   'dates': [{'original': '(30rd Dec 2024)',
#     'parsed': '2024-12-30',
#     'start': 11,
#     'end': 26},
#    {'original': '(26st Feb 2025)',
#     'parsed': '2025-02-26',
#     'start': 445,
#     'end': 460}],
#   'relationship_gold': [{'date': '2025-02-26',
#     'date_position': 445,
#     'diagnoses': [{'diagnosis': 'fibromyalgia', 'position': 751}]},
#    {'date': '2025-04-12',
#     'date_position': 15,
#     'diagnoses': [{'diagnosis': 'hypothyroidism', 'position': 1195}]}],
#   'patient_id': 4,
#   'note_id': 13},
#  {'note_text': "Rheumatology CONSULT (08.01.25): rule out adrenal_insufficiency taper medication\n Follow-up appointment scheduled in 3 months.\nPsychiatric: Alert and oriented x3. Mood and affect appropriate.\n\nBasic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.\n HEENT: Normocephalic, atraumatic. Assessment includes congenital malformation. Pupils equal, round, and reactive to light.The patient was advised to return if symptoms worsen.\nHeart: Regular rate and rhythm, no murmurs.CLINIC VISIT (29st Jan 2025): frequent urination unchanged Skin: No rashes, lesions, or abnormal pigmentation. Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. Patient has a history of obesity. Musculoskeletal: Full range of motion in all extremities. No edema or deformity noted. Will continue current medication regimen and reassess in 3 months. Good turgor and hydration. The patient's vital signs are stable.\n Imaging studies were reviewed with the patient.Patient instructed to follow up with specialist for further evaluation.\nA review of systems was otherwise negative. Urinalysis negative for blood, protein, and leukocyte esterase.  new dx of pituitary_adenoma f/u in 3 months\n\nNeurology CONSULT (08/03/25): resolving pituitary_adenoma refer to Rheumatology\n\nURGENT REVIEW (2025-04-11): nausea/vomiting.new dx of IBS\n\nLabs (16 Apr'25): high cortisol.rule out gout",
#   'entities_list': [{'label': 'adrenal_insufficiency', 'start': 42, 'end': 63},
#    {'label': 'pituitary_adenoma', 'start': 1170, 'end': 1187},
#    {'label': 'ibs', 'start': 1340, 'end': 1343},
#    {'label': 'gout', 'start': 1386, 'end': 1390},
#    {'label': 'congenital malformation', 'start': 339, 'end': 362},
#    {'label': 'obesity', 'start': 703, 'end': 710}],
#   'dates': [{'original': '(08.01.25)',
#     'parsed': '2025-01-08',
#     'start': 21,
#     'end': 31},
#    {'original': '(29st Jan 2025)',
#     'parsed': '2025-01-29',
#     'start': 517,
#     'end': 532}],
#   'relationship_gold': [{'date': '2025-01-08',
#     'date_position': 21,
#     'diagnoses': [{'diagnosis': 'adrenal_insufficiency', 'position': 42}]},
#    {'date': '2025-01-29',
#     'date_position': 517,
#     'diagnoses': [{'diagnosis': 'pituitary_adenoma', 'position': 1170}]},
#    {'date': '2025-04-11',
#     'date_position': 16,
#     'diagnoses': [{'diagnosis': 'ibs', 'position': 1340}]}],
#   'patient_id': 5,
#   'note_id': 14},
#  {'note_text': "Labs (07 May 2024): normal CBC. rule out pituitary_adenoma\n\nNo known drug allergies or adverse reactions reported.\nX-ray (09 May'24): consistent w/ pneumonia. imp: pneumonia\n\n EKG shows normal sinus rhythm without ST changes or conduction abnormalities. Patient reports compliance with current medication regimen.Phone note((03/06/24)): resolved.\nSkin: No rashes, lesions, or abnormal pigmentation. Good turgor and hydration. taper medication\n Chest X-ray reveals clear lung fields without infiltrates or effusions.\nURGENT REVIEW (2024-06-25): chest pain. likely stroke\n\nF/U (07st Jul 2024): relapse. new diagnosis of tension_headache schedule PET scan\n\n\nEKG shows normal sinus rhythm without ST changes or conduction abnormalities.Cardiology CONSULT (10 Jul 2024) Imaging studies were reviewed with the patient. She denies any nausea, vomiting, or diarrhea. GI: Bowel sounds present in all four quadrants.\n\nPatient advised to maintain a symptom diary for review at next appointment.Neurological exam within normal limits. Neurological exam within normal limits. Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. No hepatosplenomegaly. : resolving COPD admit to hospital\n\nRheumatology CONSULT (10/08/24): new diagnosis of anxiety observe and reassess",
#   'entities_list': [{'label': 'pituitary_adenoma', 'start': 41, 'end': 58},
#    {'label': 'pneumonia', 'start': 148, 'end': 157},
#    {'label': 'stroke', 'start': 563, 'end': 569},
#    {'label': 'tension_headache', 'start': 618, 'end': 634},
#    {'label': 'copd', 'start': 1161, 'end': 1165},
#    {'label': 'anxiety', 'start': 1235, 'end': 1242}],
#   'dates': [{'original': '(2024-06-25)',
#     'parsed': '2025-06-24',
#     'start': 530,
#     'end': 542},
#    {'original': '(10 Jul 2024)',
#     'parsed': '2024-07-10',
#     'start': 751,
#     'end': 1149}],
#   'relationship_gold': [{'date': '2024-06-25',
#     'date_position': 16,
#     'diagnoses': [{'diagnosis': 'stroke', 'position': 563}]},
#    {'date': '2024-07-10',
#     'date_position': 751,
#     'diagnoses': [{'diagnosis': 'copd', 'position': 1161}]}],
#   'patient_id': 6,
#   'note_id': 15},
#  {'note_text': "PET scan (11/01/25): reveals hyp Skin: No rashes, lesions, or abnormal pigmentation.\nPatient instructed to follow up with specialist for further evaluation. Good turgor and hydration.\nHe denies any fever, chills, or night sweats. Will continue current medication regimen and  Will continue current medication regimen and reassess in 3 months. Patient is afebrile with normal vital signs. The plan was discussed with the patient, who understands and agrees.\nCT scan of the head shows no acute intracranial abnormalities. Lungs clear to auscultation bilaterally. CT scan of the head shows no acute intracranial abnormalities. disorder of liver was discussed.\nChest X-ray reveals clear lung fields without infiltrates or effusions. reassess in 3 months. neoplasm of pituitary gland was discussed. erlipidemia. Patient has a history of congenital malformation.\nHEENT: Normocephalic, atraumatic. Pupils equal, round, and reactive to light. Current medications include: lisinopril 10mg daily, metformin 500mg twice daily, and atorvastatin 20mg at bedtime. imp: hyperlipidemia\n\n No acute distress noted on examination.Phone note((20/02/25)): improved. taper medication\n\nWill order additional laboratory studies at next visit if symptoms persist.\nPatient was instructed on proper medication administration techniques. He denies any fever, chills, or night sweats.\nURGENT REVIEW (17 Apr'25): dizziness. new dx of myeloma",
#   'entities_list': [{'label': 'hyperlipidemia', 'start': 29, 'end': 805},
#    {'label': 'hyperlipidemia', 'start': 1055, 'end': 1069},
#    {'label': 'myeloma', 'start': 1404, 'end': 1411},
#    {'label': 'neoplasm of pituitary gland', 'start': 751, 'end': 778},
#    {'label': 'disorder of liver', 'start': 624, 'end': 641},
#    {'label': 'congenital malformation', 'start': 832, 'end': 855}],
#   'dates': [{'original': '(11/01/25)',
#     'parsed': '2025-01-11',
#     'start': 9,
#     'end': 19},
#    {'original': '(20/02/25)',
#     'parsed': '2025-02-20',
#     'start': 1122,
#     'end': 1132}],
#   'relationship_gold': [{'date': '2025-01-11',
#     'date_position': 9,
#     'diagnoses': [{'diagnosis': 'hyperlipidemia', 'position': 1055},
#      {'diagnosis': 'hyperlipidemia', 'position': 1055}]}],
#   'patient_id': 7,
#   'note_id': 16},
#  {'note_text': 'Evaluation((19 Sep 2024)): pt presents w/ headache x3 months.\nCT scan of the head shows no acute intracranial abnormalities. Will order additional laboratory studies at next visit if symptoms persist. rule out pituitary_adenoma\n\nPatient is afebrile with normal vital signs.\nX-ray (18th Nov 2024): no significant findings. imp: COPD\n EKG shows normal sinus rhythm without ST changes or conduction abnormalities. Patient tolerated the procedure well.\nNew pt((21 Nov 2024)): pt presents w/ back pain. rule out gout\n CT scan of the head shows no acute intracranial abnormalities.\nPhone note((26nd Nov 2024)): remission.\nImaging studies were reviewed with the patient.\nBasic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9. Psychiatric: Alert and oriented x3. Mood and affect appropriate. schedule PET scan\n\nEvaluation((17/12/24)): pt pre sents w/ shortness of breath. resolving prolactinoma\n\nRheumatology CONSULT (20th Dec 2024): consistent w MRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke. Cardiovascular: Regular rate and rhythm.\nPatient tolerated the procedure well. No murmurs, rubs, or gallops. Normal S1 and S2. / pneumonia f/u in 6 months\n\nCLINIC VISIT (03rd Feb 20;25): fever slightly improved rule out epilepsy observe and reassess',
#   'entities_list': [{'label': 'pituitary_adenoma', 'start': 210, 'end': 227},
#    {'label': 'copd', 'start': 327, 'end': 331},
#    {'label': 'gout', 'start': 507, 'end': 511},
#    {'label': 'prolactinoma', 'start': 910, 'end': 922},
#    {'label': 'pneumonia', 'start': 1194, 'end': 1203},
#    {'label': 'epilepsy', 'start': 1285, 'end': 1293}],
#   'dates': [{'original': '(26nd Nov 2024)',
#     'parsed': '2024-11-26',
#     'start': 587,
#     'end': 602},
#    {'original': '(20th Dec 2024)',
#     'parsed': '2024-12-20',
#     'start': 945,
#     'end': 960}],
#   'relationship_gold': [{'date': '2024-12-20',
#     'date_position': 945,
#     'diagnoses': [{'diagnosis': 'pneumonia', 'position': 1194}]},
#    {'date': '2025-02-03',
#     'date_position': 15,
#     'diagnoses': [{'diagnosis': 'epilepsy', 'position': 1285}]}],
#   'patient_id': 8,
#   'note_id': 17},
#  {'note_text': "Internal Medicine CONSULT (30-10-2024): new dx of prolactinoma refer to Oncology\n\nWill order additional laboratory studies at next visit if symptoms persist.\nInitial assessment((16th Nov 2 024)): pt presents w/ chest pain.\nThe plan was discussed with the patient, who understands and agrees. rule out depression\n\nURGENT REVIEW (09st Jan 2025): mood changes.\nEKG shows normal sinus rhythm without ST changes or conduction abnormalities. confirmed bipolar_disorder[diagnos;is]\n\nURGENT REVIEW (17th Jan 2025): headache x3 months. He denies any fever, chills, or night sweats. Urinalysis negative for blood, protein, and leukocyte esterase. Current medications include: lisinopril 10mg daily, metformin 500mg twice daily, and atorvastatin 20mg at bedtime. consistent w/ hypothyroidism\n\nF/U (04 Feb 2025): remission.\nHeart: Regular rate and rhythm, no murmurs. unclear etiology, could be Parkinson's_disea,se vs adrenal_insufficiency switch to atorvastatin\n\nCLINIC VISIT (24/02/25): headac Cardiovascular: Regular rate and rhythm. No murmurs, rubs, or gallops. Normal S1 and S2. Psychiatric: Alert and oriented x3. Mood and affect appropriate. The plan was discussed with the patient, who understands and agrees. he x1 week remission suspect gout observe and reassess",
#   'entities_list': [{'label': 'prolactinoma', 'start': 50, 'end': 62},
#    {'label': 'depression', 'start': 301, 'end': 311},
#    {'label': 'bipolar_disorder', 'start': 446, 'end': 462},
#    {'label': 'hypothyroidism', 'start': 766, 'end': 780},
#    {'label': 'adrenal_insufficiency', 'start': 907, 'end': 928},
#    {'label': 'gout', 'start': 1237, 'end': 1241}],
#   'dates': [{'original': '(30-10-2024)',
#     'parsed': '2024-10-30',
#     'start': 26,
#     'end': 38},
#    {'original': '(24/02/25)',
#     'parsed': '2025-02-24',
#     'start': 966,
#     'end': 976}],
#   'relationship_gold': [{'date': '2024-10-30',
#     'date_position': 26,
#     'diagnoses': [{'diagnosis': 'prolactinoma', 'position': 50}]},
#    {'date': '2024-11-16',
#     'date_position': 21,
#     'diagnoses': [{'diagnosis': 'depression', 'position': 301}]},
#    {'date': '2025-02-24',
#     'date_position': 966,
#     'diagnoses': [{'diagnosis': 'gout', 'position': 1237}]}],
#   'patient_id': 9,
#   'note_id': 18},
#  {'note_text': "New patient((28 Jan 2025)): pt presents w/ Medications were reconciled during the visit. Patient advised to maintain a symptom diary for review at next appointment. Noted ebola virus disease in medical history. Patient has a history of congenital malformation. Cardiovascular: Regular rate and rhythm. Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. Patient tolerated the procedure well. No murmurs, rubs, or gallops. Normal S1 and S2. Patient reports occasional use of over-the-counter analgesics for pain management.\nLymphatic: No cervical, axillary, or inguinal lymphadenopathy.  excessive thirst. resolving microadenoma\n\n\nMusculoskeletal: Full range of motion in all extremities. No edema or deformity noted.Evaluation((22nd Feb 2025)): pt presents w/ nausea/vomiting.\nThe patient was advised to return if symptoms worsen. new dx of Cushing's_syndrome\n\nPhone note((21st Mar 2025)): resolved. increase dose\n\nHeart: Regular rate and rhythm, no murmurs. Noted hyperlipidemia in medical history. disorder of pancreas was discussed.\n\n No known drug allergies or adverse reactions reported.The patient was advised to return if symptoms worsen.Labs (29rd Mar 2025): positive ANA. rule out cluster_headache\n\nRecommended lifestyle modifications including diet changes and regular exercise. Labs from this morning were unremarkable.\n Basic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.Phone note((30 Apr'25)): progressive. taper medication",
#   'entities_list': [{'label': 'microadenoma', 'start': 626, 'end': 638},
#    {'label': 'cluster_headache', 'start': 1201, 'end': 1217},
#    {'label': 'ebola virus disease', 'start': 171, 'end': 190},
#    {'label': 'congenital malformation', 'start': 236, 'end': 259},
#    {'label': 'hyperlipidemia', 'start': 976, 'end': 990},
#    {'label': 'disorder of pancreas', 'start': 1011, 'end': 1031}],
#   'dates': [{'original': '(28 Jan 2025)',
#     'parsed': '2025-01-28',
#     'start': 12,
#     'end': 25},
#    {'original': '(22nd Feb 2025)',
#     'parsed': '2025-02-22',
#     'start': 738,
#     'end': 753}],
#   'relationship_gold': [{'date': '2025-01-28',
#     'date_position': 12,
#     'diagnoses': [{'diagnosis': 'microadenoma', 'position': 626}]}],
#   'patient_id': 10,
#   'note_id': 19},
#  {'note_text': 'CLINIC VISIT (27th Jan 2025): weight los s remission rule out hyperlipidemia cont current medications\n\nHeart: Regular rate and rhythm, no murmurs. neoplasm of pituitary gland was discussed.\nThe patient was counseled on lifestyle modifications. Patient has a history of meningitis. Noted hydrocephalus in medical history.\n The patient was advised to return if symptoms worsen.\nPatient tolerated the procedure well.\nGI: Bowel sounds present in all four quadrants. No hepatosplenomegaly.X-r;ay (22 Feb 2025): co Abdomen: Soft, non-tender, non-distended. Patient advised to maintain a symptom diary for review at next appointment. A review of systems was otherwise negative.\nReferral placed for physical therapy twice weekly for 6 weeks. nsistent with gout.imp: gout\n GI: Bowel sounds present in all four quadrants. The patient was advised to return if symptoms worsen. MRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke. Musculoskeletal: Full range of motion in all extremities. No edema or deformity noted. No hepatosplenomegaly.\n\nRecommended lifestyle modifications including diet changes and regular exercise. No known drug allergies or adverse reactions reported.Phone note((26/02/2 025)): fluctuating.refer to Rheumatology\n\nCT scan of the head shows no acute intracranial abnormalities.\n Abdomen: Soft, non-tender, non-distended.URGENT REVIEW (12 Ap.r 2025): joint pain.resolving hypothyroidi sm',
#   'entities_list': [{'label': 'hyperlipidemia', 'start': 62, 'end': 76},
#    {'label': 'gout', 'start': 748, 'end': 752},
#    {'label': 'hypothyroidism', 'start': 57, 'end': 71},
#    {'label': 'neoplasm of pituitary gland', 'start': 147, 'end': 174},
#    {'label': 'hydrocephalus', 'start': 287, 'end': 300},
#    {'label': 'meningitis', 'start': 269, 'end': 279}],
#   'dates': [{'original': '(27th Jan 2025)',
#     'parsed': '2025-01-27',
#     'start': 13,
#     'end': 28},
#    {'original': '(22 Feb 2025)',
#     'parsed': '2025-02-22',
#     'start': 491,
#     'end': 504}],
#   'relationship_gold': [{'date': '2025-01-27',
#     'date_position': 13,
#     'diagnoses': [{'diagnosis': 'hyperlipidemia', 'position': 62}]},
#    {'date': '2025-02-22',
#     'date_position': 491,
#     'diagnoses': [{'diagnosis': 'gout', 'position': 748}]},
#    {'date': '2025-04-12',
#     'date_position': 16,
#     'diagnoses': [{'diagnosis': 'hypothyroidism', 'position': 57}]}],
#   'patient_id': 1,
#   'note_id': 20},
# ...
#   'entities_list': [{'label': 'hyperlipidemia', 'start': 64, 'end': 78},
#    {'label': 'myeloma', 'start': 617, 'end': 624},
#    {'label': 'anxiety', 'start': 816, 'end': 823},
#    {'label': 'migraine', 'start': 1350, 'end': 1358},
#    {'label': 'pituitary macroadenoma', 'start': 1283, 'end': 1305},
#    {'label': 'radiologic infiltrate of lung', 'start': 452, 'end': 481}],
#   'dates': [{'original': '(17.12.24)',
#     'parsed': '2024-12-17',
#     'start': 345,
#     'end': 355},
#    {'original': '(09rd Feb 2025)',
#     'parsed': '2025-02-09',
#     'start': 1072,
#     'end': 1087}],
#   'relationship_gold': [{'date': '2025-02-09',
#     'date_position': 1072,
#     'diagnoses': [{'diagnosis': 'migraine', 'position': 1350}]}],
#   'patient_id': 5,
#   'note_id': 94},
#  {'note_text': "Labs (25/11/2024): positive ANA.res Patient is afebrile with normal vital signs. MRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke. Patient reports occasional use of over-the-counter analgesics for pain management.\nUrinalysis negative for blood, protein, and leukocyte esterase. Patient has a history of asthma. Patient reports compliance with current medication regimen. Noted pituitary macroadenoma in medical history. ;olving schizophrenia\n\nWill order additional laboratory studies at next visit if symptoms persist. congenital malformation was discussed.\n CT scan of the head shows no acute intracranial abnormalities.CLINIC VISIT (16 Jan'25): back pain resolved reso Medications were reconciled during the visit. Patient given educational materials regarding disease management. Patient given educational materials regarding disease management.\nImaging studies were reviewed with the patient. lvi.ng COPD taper medication\n\n Will order additional laboratory studies at next visit if symptoms persist.\n Basic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.No acute distress noted on examination.\nA review of systems was otherwise negative. Recommended lifestyle modifications including diet changes and regular exercise. Patient reports occasional use of over-the-counter analgesics for pain management.Evaluation((19/01/2025)[date,]): pt presents w/ mood changes.suspect GERD",
#   'entities_list': [{'label': 'schizophrenia', 'start': 468, 'end': 481},
#    {'label': 'copd', 'start': 944, 'end': 948},
#    {'label': 'gerd', 'start': 1451, 'end': 1455},
#    {'label': 'congenital malformation', 'start': 559, 'end': 582},
#    {'label': 'pituitary macroadenoma', 'start': 417, 'end': 439},
#    {'label': 'asthma', 'start': 343, 'end': 349}],
#   'dates': [{'original': '(25/11/2024)',
#     'parsed': '2024-11-25',
#     'start': 5,
#     'end': 17},
#    {'original': "(16 Jan'25)",
#     'parsed': '2025-01-16',
#     'start': 674,
#     'end': 685}],
#   'relationship_gold': [{'date': '2024-11-25',
#     'date_position': 5,
#     'diagnoses': [{'diagnosis': 'schizophrenia', 'position': 468}]},
#    {'date': '2025-01-16',
#     'date_position': 674,
#     'diagnoses': [{'diagnosis': 'copd', 'position': 944}]}],
#   'patient_id': 6,
#   'note_id': 95},
#  {'note_text': "Visit((08/10/24)): pt presents with joint pain. Patient has a history of neoplasm of pituitary gland. confirmed macroadenoma\n\nLungs clear to auscultation bilaterally.\n Patient reports occasional use of over-the-counter analgesics for pain management.\nChest X-ray reveals clear lung fields without infiltrates or effusions.\n\nNo known drug allergies or adverse reactions reported.Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. HEENT: Normocephalic, atraumatic. Pupils equal, round, and reactive to light.CLINIC VISIT (30 Oct'24): joint pain slightly improved resolving hyperlipidemia switch to lisinopril\n\nMRI (11/12/2024): no significant findings. imp: CT scan of the head shows no acute intracranial abnormalities. A review of systems was otherwise negative.  depression\n The plan was discussed with the patient, who understands and agrees. osteoarthritis was discussed. Complete blood count shows WBC 7.2, Hgb 13.5, Plt 250.\n\nHeart: Regular rate and rhythm, no murmurs.\nHe denies any fever, chills, or night sweats.Evaluation((12nd Jan 2025)): pt presents with excessive thirst. con Imaging studies were reviewed with the patient.\n Basic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.Cardiovascular: Regular rate and rhythm. No murmurs, rubs, or gallops. Normal S1 and S2. She denies any nausea, vomiting, or diarrhea. firmed lymphoma",
#   'entities_list': [{'label': 'macroadenoma', 'start': 112, 'end': 124},
#    {'label': 'hyperlipidemia', 'start': 583, 'end': 597},
#    {'label': 'depression', 'start': 776, 'end': 786},
#    {'label': 'lymphoma', 'start': 1381, 'end': 1389},
#    {'label': 'neoplasm of pituitary gland', 'start': 73, 'end': 100},
#    {'label': 'osteoarthritis', 'start': 857, 'end': 871}],
#   'dates': [{'original': '(11/12/2024)',
#     'parsed': '2024-12-11',
#     'start': 624,
#     'end': 636},
#    {'original': '(12nd Jan 2025)',
#     'parsed': '2025-01-12',
#     'start': 1043,
#     'end': 1058}],
#   'relationship_gold': [{'date': '2024-12-11',
#     'date_position': 624,
#     'diagnoses': [{'diagnosis': 'depression', 'position': 776}]},
#    {'date': '2025-01-12',
#     'date_position': 1043,
#     'diagnoses': [{'diagnosis': 'lymphoma', 'position': 1381}]}],
#   'patient_id': 7,
#   'note_id': 96},
#  {'note_text': "F/U (31 Aug 2024): resolved A review of systems was otherwise negative. MRI of the brain demonstrates age-appropriate atrophy without evidence of mass or stroke. Urinalysis negative for blood, protein, and leukocyte esterase. EKG shows normal sinus rhythm without ST changes or conduction abnormalities. . rule out macroadenoma observe and reassess\n The patient was advised to return if symptoms worsen.\n\nAbdomen: Soft, non-tender, non-distended.\n\nGI: Bowel sounds present in all four quadrants. No hepatosplenomegaly.Lungs clear to auscultation bilaterally.CT scan of the head shows no acute intracranial abnormalities. Noted congenital malformation in medical history.\n Patient tolerated the procedure well.Labs (15-09-2024): low TSH. unclear etiology,could be Parkinson's_dise Patient tolerated the procedure well. Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. The patient was advised to return if symptoms worsen. ase vs bipolar_disorder\n\n\nA review of systems was otherwise negative.CT (07th Nov 2024): shows 2.7cm mass in pancreas. Noted cerebral hemorrhage in medical history.\nThe patient was advised to return if symptoms worsen. imp: bronchitis\n\n Patient reports occasional use of over-the-counter analgesics for pain management.CLINIC VISIT (29 Nov'24): shortness of breath fluctuating suspect tension_headache switch to fluoxetine",
#   'entities_list': [{'label': 'macroadenoma', 'start': 315, 'end': 327},
#    {'label': 'bipolar_disorder', 'start': 942, 'end': 958},
#    {'label': 'bronchitis', 'start': 1159, 'end': 1169},
#    {'label': 'tension_headache', 'start': 1320, 'end': 1336},
#    {'label': 'congenital malformation', 'start': 627, 'end': 650},
#    {'label': 'cerebral hemorrhage', 'start': 1060, 'end': 1079}],
#   'dates': [{'original': '(31 Aug 2024)',
#     'parsed': '2024-08-31',
#     'start': 4,
#     'end': 17},
#    {'original': '(15-09-2024)',
#     'parsed': '2024-09-15',
#     'start': 714,
#     'end': 726}],
#   'relationship_gold': [{'date': '2024-08-31',
#     'date_position': 4,
#     'diagnoses': [{'diagnosis': 'macroadenoma', 'position': 315}]},
#    {'date': '2024-09-15',
#     'date_position': 714,
#     'diagnoses': [{'diagnosis': 'bipolar_disorder', 'position': 942}]}],
#   'patient_id': 8,
#   'note_id': 97},
#  {'note_text': "Phone note((12-10-2024)): slightly improved. observe and reassess\n\nF/U (11 Dec 2024): progress.ive. suspect tension_headache switch to cabergoline\n\nPhone note((17rd Jan 2025)): slightly improved. increase dose\n\nOncology CONSULT (01/03/2025): confirmed cluster_head She denies any nausea, vomiting, or diarrhea. Neurological exam within normal limits.\nThe patient's vital signs are stable. Cardiovascular: Regular rate and rhythm. The patient was counseled on lifestyle modifications. No murmurs, rubs, or gallops. Normal S1 and S2. Patient was instructed on proper medication administration techniques.\nHe denies any fever, chills, or night sweats. ache schedule X-ray\n\nX-ray (20nd Apr 2025): evidence of edema. Recommended lifestyle modifications including diet changes and regular exercise. imp: COPD\n\nOncology CONSULT (13 Jun'25): likely; tension_headache f/u in 3 months\n\n Will order additional laboratory studies at next visit if symptoms persist.Labs (04rd Jul 2025): elevated CRP. suspect adrenal_insufficiency\n\n Will continue current medication regimen and reassess in 3 months. Skin: No rashes, lesions, or abnormal pigmentation.\nChest X-ray reveals clear lung fields without infiltrates or effusions. Good turgor and hydration.URGENT REVIEW (2025-07-19): fatigue. unclear etiology,could be hypothyroidism vs bronchitis",
#   'entities_list': [{'label': 'tension_headache', 'start': 108, 'end': 124},
#    {'label': 'cluster_headache', 'start': 252, 'end': 653},
#    {'label': 'copd', 'start': 798, 'end': 802},
#    {'label': 'adrenal_insufficiency', 'start': 996, 'end': 1017},
#    {'label': 'hypothyroidism', 'start': 1300, 'end': 1314},
#    {'label': 'bronchitis', 'start': 1318, 'end': 1328}],
#   'dates': [{'original': '(01/03/2025)',
#     'parsed': '2025-03-01',
#     'start': 228,
#     'end': 240},
#    {'original': "(13 Jun'25)",
#     'parsed': '2025-06-13',
#     'start': 821,
#     'end': 832}],
#   'relationship_gold': [{'date': '2025-03-01',
#     'date_position': 228,
#     'diagnoses': [{'diagnosis': 'cluster_headache', 'position': 252}]},
#    {'date': '2025-06-13',
#     'date_position': 821,
#     'diagnoses': [{'diagnosis': 'tension_headache', 'position': 108}]},
#    {'date': '2025-07-19',
#     'date_position': 16,
#     'diagnoses': [{'diagnosis': 'hypothyroidism', 'position': 1300},
#      {'diagnosis': 'bronchitis', 'position': 1318}]}],
#   'patient_id': 9,
#   'note_id': 98},
#  {'note_text': "F/U (2025-02-23): fluctuating. confirmed multiple_sclerosis cont current medications\n\n Follow-up appointment scheduled in 3 months.\nMedications were reconciled during the visit.\nWill continue current medication regimen and reassess in 3 months.PET scan (13-04-2025): shows 3.1cm mass in thyroid. Neurological exam within normal limits. imp: Parkinson's_disease\n\n\nWill order additional laboratory studies at next visit if symptoms persist.\nBasic metabolic panel within normal limits with sodium 140, potassium 4.2, creatinine 0.9.\nLymphatic: No cervical, axillary, or inguinal lymphadenopathy. Medication dosages were adjusted based on recent laboratory findings.Phone note((08rd May 2025)): remission. schedule Ultrasound\n\n No known drug allergies or adverse reactions reported.CLINIC VISIT (26/05/2025): nausea A review of systems was otherwise negative.\n The patient's vital signs are stable.\nPatient reports compliance with current medication regimen. Patient has a history of congenital malformation. Complete blood count shows WBC 7.2, Hgb 13.5, Plt 250.\nPatient reports compliance with current medication regimen. pituitary adenoma was discussed.\nLungs clear to auscultation bilaterally. Lungs clear to auscultation bilaterally.Lungs clear to auscultation bilaterally. Assessment includes pituitary macroadenoma. Noted soft tissue lesion in medical history. The patient was advised to return if symptoms worsen. /vomiting unchanged resolving COPD admit to hospital",
#   'entities_list': [{'label': 'multiple_sclerosis', 'start': 41, 'end': 59},
#    {'label': 'copd', 'start': 1448, 'end': 1452},
#    {'label': 'pituitary macroadenoma', 'start': 1295, 'end': 1317},
#    {'label': 'soft tissue lesion', 'start': 1325, 'end': 1343},
#    {'label': 'congenital malformation', 'start': 980, 'end': 1003},
#    {'label': 'pituitary adenoma', 'start': 1120, 'end': 1137}],
#   'dates': [{'original': '(2025-02-23)',
#     'parsed': '2023-02-25',
#     'start': 4,
#     'end': 16},
#    {'original': '(26/05/2025)',
#     'parsed': '2025-05-26',
#     'start': 791,
#     'end': 803}],
#   'relationship_gold': [{'date': '2025-02-23',
#     'date_position': 6,
#     'diagnoses': [{'diagnosis': 'multiple_sclerosis', 'position': 41}]},
#    {'date': '2025-05-26',
#     'date_position': 791,
#     'diagnoses': [{'diagnosis': 'copd', 'position': 1448}]}],
#   'patient_id': 10,
#   'note_id': 99},
#  {'note_text': 'CLINIC VISIT (15/06/2025): Patient was Current medications include: lisinopril 10mg daily, metformin 500mg twice daily, and atorvastatin 20mg at bedtime. Cardiovascular: Regular rate and rhythm. Skin: No rashes, lesions, or abnormal pigmentation. Good turgor and hydration. congenital malformation was discussed. No murmurs, rubs, or gallops. Labs from this morning were unremarkable.\n\nHe denies any fever, chills, or night sweats.Past medical history is non-contributory. Patient has a history of cerebral hemorrhage. Normal S1 and S2. The patient was counseled on lifestyle modifications. Referral placed for physical therapy twice weekly for 6 weeks.\nFollow-up appointment scheduled in 3 months. CT scan of the head shows no acute intracranial abnormalities.  diagnosed with pituitary adenoma last year. Assessment includes soft tissue lesion. Follow-up M Lymphatic: No cervical, axillary, or inguinal lymphadenopathy. Past medical history is non-contributory. GI: Bowel sounds present in all four quadrants. No hepatosplenomegaly. Noted pituitary adenoma in medical history. RI shows stable appearance compared to six months ago. The patient was diagnosed with acromegaly 2 years ago and has been on medication since then. Recommended lifestyle modifications including diet changes and regular exercise. Visual symptoms appeared three weeks ago. Headaches started last week and have persisted since then.\nPatient is afebrile with normal vital signs.',
#   'entities_list': [{'label': 'pituitary_adenoma', 'start': 778, 'end': 795},
#    {'label': 'acromegaly', 'start': 1165, 'end': 1175},
#    {'label': 'pituitary adenoma', 'start': 1041, 'end': 1058},
#    {'label': 'congenital malformation', 'start': 274, 'end': 297},
#    {'label': 'soft tissue lesion', 'start': 827, 'end': 845},
#    {'label': 'cerebral hemorrhage', 'start': 498, 'end': 517}],
#   'dates': [{'original': '(15/06/2025)',
#     'parsed': '2025-06-15',
#     'start': 13,
#     'end': 25}],
#   'relationship_gold': [{'date': '2025-06-15',
#     'date_position': 13,
#     'diagnoses': [{'diagnosis': 'pituitary_adenoma', 'position': 778},
#      {'diagnosis': 'acromegaly', 'position': 1165}]}],
#   'patient_id': 1,
#   'note_id': 100}]

# %%
#Create training pairs
processed_df = create_training_pairs(samples)
processed_df
# Out:
#                                                    text  \
# 0     Ultrasound (30nd Jun 2024): no significant fin...
# 1     Ultrasound (30nd Jun 2024): no significant fin...
# 2     Ultrasound (30nd Jun 2024): no significant fin...
# 3     Ultrasound (30nd Jun 2024): no significant fin...
# 4     Ultrasound (30nd Jun 2024): no significant fin...
# ...                                                 ...
# 1237  CLINIC VISIT (15/06/2025): Patient was Current...
# 1238  CLINIC VISIT (15/06/2025): Patient was Current...
# 1239  CLINIC VISIT (15/06/2025): Patient was Current...
# 1240  CLINIC VISIT (15/06/2025): Patient was Current...
# 1241  CLINIC VISIT (15/06/2025): Patient was Current...
#
#                                             marked_text  ent1_start  ent1_end  \
# 0     Ultrasound (30nd Jun 2024): no significant fin...          57        63
# 1     Ultrasound (30nd Jun 2024): no significant fin...          57        63
# 2     Ultrasound (30nd Jun 2024): no significant fin...         410       427
# 3     Ultrasound (30nd Jun 2024): no significant fin...         410       427
# 4     Ultrasound (30nd Jun 2024): no significant fin...         491       511
# ...                                                 ...         ...       ...
# 1237  CLINIC VISIT [E2] (15/06/2025) [/E2]: Patient ...        1165      1175
# 1238  CLINIC VISIT [E2] (15/06/2025) [/E2]: Patient ...        1041      1058
# 1239  CLINIC VISIT [E2] (15/06/2025) [/E2]: Patient ...         274       297
# 1240  CLINIC VISIT [E2] (15/06/2025) [/E2]: Patient ...         827       845
# 1241  CLINIC VISIT [E2] (15/06/2025) [/E2]: Patient ...         498       517
#
#       ent2_start  ent2_end  label  patient_id  note_id  distance
# 0            311       326      1           1        0       254
# 1            587       602      0           1        0       530
# 2            311       326      0           1        0        99
# 3            587       602      0           1        0       177
# 4            311       326      0           1        0       180
# ...          ...       ...    ...         ...      ...       ...
# 1237          13        25      1           1      100      1152
# 1238          13        25      0           1      100      1028
# 1239          13        25      0           1      100       261
# 1240          13        25      0           1      100       814
# 1241          13        25      0           1      100       485
#
# [1242 rows x 10 columns]

# %%
#Handle class imbalance
balanced_df, class_weights = handle_class_imbalance(processed_df, method='weighted')
class_weights
# Out:
# tensor([0.2721, 1.7279])

# %%
#Train-test split
train_df, test_df = train_test_split(balanced_df, test_size=0.2, random_state=42, stratify=balanced_df['label'])

# %%
#Tokenizer
model_name = "emilyalsentzer/Bio_ClinicalBERT"
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer = add_special_tokens(tokenizer)

# %%
#Data prep
train_dataset = Dataset.from_pandas(train_df[['marked_text', 'label']])
test_dataset = Dataset.from_pandas(test_df[['marked_text', 'label']])

train_tokenized = train_dataset.map(lambda x: tokenize_function(x, tokenizer, max_length=256), batched=True)
test_tokenized = test_dataset.map(lambda x: tokenize_function(x, tokenizer, max_length=256), batched=True)

train_tokenized.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_tokenized.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
# Out:
# Map:   0%|          | 0/993 [00:00<?, ? examples/s]
# Map:   0%|          | 0/249 [00:00<?, ? examples/s]

# %%
#Model creation
model = BertRC(
    model_name=model_name,
    tokenizer=tokenizer,
    num_labels=2,
    class_weights=class_weights
)
# Out:
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`

# %%
#Training args
training_args = TrainingArguments(
    output_dir="./bert_rc_results",
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="f1_macro",
    greater_is_better=True,
    num_train_epochs=3,
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    warmup_ratio=0.1,
    weight_decay=0.01,
    logging_steps=50,
    fp16=torch.cuda.is_available(),
    report_to=[],
    seed=42,
)

# %%
#Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_tokenized,
    eval_dataset=test_tokenized,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
)
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9656\4255296953.py:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
#Training
trainer.train()
# Out:
# c:\Users\Satyam\Downloads\pituitary_adenoma\venv\lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='375' max='375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [375/375 1:36:42, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#       <th>F1 Micro</th>
#       <th>F1 Weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.712200</td>
#       <td>0.822181</td>
#       <td>0.863454</td>
#       <td>0.463362</td>
#       <td>0.863454</td>
#       <td>0.800183</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.673500</td>
#       <td>0.719191</td>
#       <td>0.815261</td>
#       <td>0.488661</td>
#       <td>0.815261</td>
#       <td>0.785719</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.496700</td>
#       <td>0.754170</td>
#       <td>0.787149</td>
#       <td>0.504933</td>
#       <td>0.787149</td>
#       <td>0.776641</td>
#     </tr>
#   </tbody>
# </table><p>
# c:\Users\Satyam\Downloads\pituitary_adenoma\venv\lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# c:\Users\Satyam\Downloads\pituitary_adenoma\venv\lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# TrainOutput(global_step=375, training_loss=0.6302923380533855, metrics={'train_runtime': 5818.9495, 'train_samples_per_second': 0.512, 'train_steps_per_second': 0.064, 'total_flos': 0.0, 'train_loss': 0.6302923380533855, 'epoch': 3.0})

# %%
#Evaluation
eval_results = trainer.evaluate(test_tokenized)
print("Test Results:")
for metric, value in eval_results.items():
    if not metric.startswith('eval_'):
        continue
    clean_metric = metric.replace('eval_', '')
    print(f"{clean_metric}: {value:.4f}")
# Out:
# c:\Users\Satyam\Downloads\pituitary_adenoma\venv\lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='16' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16/16 01:23]
#     </div>
# Test Results:
# loss: 0.7542
# accuracy: 0.7871
# f1_macro: 0.5049
# f1_micro: 0.7871
# f1_weighted: 0.7766
# runtime: 89.2447
# samples_per_second: 2.7900
# steps_per_second: 0.1790

# %%
#Save model
trainer.save_model("./bert_rc_final_model")
tokenizer.save_pretrained("./bert_rc_final_model")
